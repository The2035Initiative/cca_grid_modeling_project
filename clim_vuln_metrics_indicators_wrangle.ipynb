# %% [markdown]
# # Climate Vulnearbility Metrics Indicators Wrangle
# Author: Sofia Ingersoll
#
# Date: 2024-07-02
#
# Looking at all of the individual datasets to identify the nuances in column names, cleaning, then combining into a single csv file to read in later.
# There is a combination of 19 xlsx and 1 NETCDF file for the Climate Vulnerability Metrics Indicators.
#
#
# Quick notes before diving in:
# The funky column names that appeared in `identifying_ctracts_oversampling.ipynb` are not present here so that was likely a product of the for loop

# %%
# loading libraries
import os
import pandas as pd
import numpy as np
import geopandas as gpd 
import xarray as xr 
import rioxarray as rioxr
import rasterio 
import matplotlib.pyplot as plt

# Function to convert column names to snake_case
def to_snake_case(df):
    df.columns = df.columns.str.strip().str.replace(' ', '_').str.replace('\n', '_').str.lower()
    return df

# %% [markdown]
# ### Environmental

# %% [markdown]
# **Air Conditioning**

# %%
air_conditioning = pd.read_excel('data/Climate_Vulnerability_Metric_Indicators/BRACE_AirConditioning_797_CO_RE_CA.xlsx', sheet_name=None)
 
# collect Clim. Vuln. Factor sheet names
ac_sheetnames = list(air_conditioning.keys())

# read in sheets as df
ac_README = air_conditioning[ac_sheetnames[0]]

ac_data = air_conditioning[ac_sheetnames[1]]

ac_dict = air_conditioning[ac_sheetnames[2]]

ac_dict
# Out:
#                      Name                                          Definition  \
# 0                   ind_id                                       Indicator ID
# 1           ind_definition          Definition of indicator in plain language
# 2               reportyear               Year that the indicator was reported
# 3            race_eth_code            numeric code for a race/ethnicity group
# 4            race_eth_name                          Name of race/ethnic group
# 5                  geotype                            Type of geographic unit
# 6             geotypevalue                           Value of geographic unit
# 7                  geoname                            Name of geographic unit
# 8              county_name                  Name of county that geotype is in
# 9              county_fips             FIPS code of county that geotype is in
# 10             region_name  Adaptation Impact Region (AIR) name; see AIR_C...
# 11             region_code  Adaptation Impact Region (AIR) code; see AIR_C...
# 12        strata_name_code                               code for strata name
# 13             strata_name                                     name of strata
# 14  strata_level_name_code                              code for strata level
# 15       strata_level_name                               strata category name
# 16               numerator  Estimated number of occupied households with a...
# 17             denominator                Total number of occupied households
# 18                 percent        Percent of households with air conditioning
# 19         LL_95CI_percent  Lower limit of 95% confidence interval around ...
# 20         UL_95CI_percent          Upper limit of 95% confidence interval.
# 21              percent_se  Standard error of the estimate: measure of the...
# 22             percent_rse  Relative standard error (se/estimate * 100) ex...
# 23               CA_decile  Statewide decile ranking: 'CA_decile' groups p...
# 24                   CA_RR  California Ratio: ratio estimate/state estimat...
# 25                 version   Date/time stamp of version of data file creation
#
#    Type                                             Coding
# 0     N                                                 26
# 1     T                                          Free text
# 2     T                                               2009
# 3     T  1 = American Indian; 2 = Asian or Pacific; 3 =...
# 4     T  American Indian; Asian or Pacific; Black or Af...
# 5     T                     CO County; RE Region; CA State
# 6     N                                 FIPS ID; region id
# 7     T                         county, region name, state
# 8     T                                                NaN
# 9     T  2-digit census state code (06) plus 3-digit ce...
# 10    T                                                NaN
# 11    T  01 = North; 02 = North Coast; 03 = Bay Area; 0...
# 12    N  1 = Race_Ethnicity; 2 = Income Category; 9 = T...
# 13    T             Race_Ethnicity; Income Category; Total
# 14    N  1 = American Indian; 2 = Asian or Pacific; 3 =...
# 15    T  American Indian; Asian or Pacific; Black or Af...
# 16    N                                                NaN
# 17    N                                                NaN
# 18    N                                                NaN
# 19    N                                                NaN
# 20    N                                                NaN
# 21    N                                                NaN
# 22    N                                                NaN
# 23    N                                                NaN
# 24    N                                                NaN
# 25   DT                                mm/DD/CCYY hh:mm:ss

# %% [markdown]
# **Extreme Heat**

# %%
heat = pd.read_excel('data/Climate_Vulnerability_Metric_Indicators/BRACE_ExtremeHeat_791_CO.xlsx', sheet_name=None)
 
# collect Clim. Vuln. Factor sheet names
heat_sheetnames = list(heat.keys())

# read in sheets as df
heat_README = heat[heat_sheetnames[0]]

heat_data = heat[heat_sheetnames[1]]

heat_dict = heat[heat_sheetnames[2]]

heat_dict
# Out:
# /Users/sofiaingersoll/anaconda3/envs/eds-env/lib/python3.11/site-packages/openpyxl/worksheet/header_footer.py:48: UserWarning: Cannot parse header or footer so it will be ignored
#   warn("""Cannot parse header or footer so it will be ignored""")
#                                                 Name   \
# 0                                              ind_id
# 1                                      ind_definition
# 2                                          reportyear
# 3                                       race_eth_code
# 4                                       race_eth_name
# 5                                             geotype
# 6                                        geotypevalue
# 7                                             geoname
# 8                                         county_name
# 9                                         county_fips
# 10                                        region_name
# 11                                        region_code
# 12                                    strata_one_code
# 13                                    strata_one_name
# 14                                    strata_two_code
# 15                                    strata_two_name
# 16                                          numerator
# 17                                        denominator
# 18                                           estimate
# 19                                            LL_95CI
# 20                                            UL_95CI
# 21                                                 SE
# 22                                                RSE
# 23                                          CA_decile
# 24                                              CA_RR
# 25                                            version
# 26  NOTE: Blank cells indicate data is not availab...
#
#                                            Definition Type  \
# 0                     Indicator identification number    N
# 1   Indicator (full) name and definition in plain ...    T
# 2             Year(s) that the indicator was reported    T
# 3             Numeric code for a race/ethnicity group    T
# 4                        Name of race/ethnicity group    T
# 5                             Type of geographic unit    T
# 6                            Value of geographic unit    T
# 7                             Name of geographic unit    T
# 8                   Name of county that geotype is in    T
# 9              FIPS code of county that geotype is in    T
# 10                                     Name of region    T
# 11                             Numeric code of region    T
# 12                   Numeric code of the first strata    T
# 13                           Name of the first strata    T
# 14                  Numeric code of the second strata    T
# 15                          Name of the second strata    T
# 16            Numeric value of numerator of indicator    N
# 17                Total Population in geographic unit    N
# 18              Projected number of extreme heat days    N
# 19  Lower limit of 95% confidence interval around ...    N
# 20          Upper limit of 95% confidence interval.      N
# 21  Standard error of the estimate: measure of the...    N
# 22  Relative standard error (se/estimate * 100) ex...    N
# 23  Statewide decile ranking: 'CA_decile' groups p...    N
# 24  California Ratio: ratio estimate/state estimat...    N
# 25   Date/time stamp of version of data file creation   DT
# 26                                                NaN  NaN
#
#                                                Coding
# 0                                                 791
# 1                                                 NaN
# 2                             2040-2060 and 2080-2099
# 3                                             9=Total
# 4                                               Total
# 5                          CO= County CT=Census Tract
# 6   FIPS ID for counties (5-characters in length s...
# 7                                                 NaN
# 8                                                 NaN
# 9                                                 NaN
# 10                                See AIR_Regions tab
# 11                                See AIR_Regions tab
# 12                                     Not Applicable
# 13                                     Not Applicable
# 14                                     Not Applicable
# 15                                     Not Applicable
# 16           Temperature Threshold (Fahrenheit units)
# 17                                     Not Applicable
# 18                                                NaN
# 19                                     Not Applicable
# 20                                     Not Applicable
# 21                                     Not Applicable
# 22                                     Not Applicable
# 23                                     Not Applicable
# 24                                     Not Applicable
# 25                                mm/DD/CCYY hh:mm:ss
# 26                                                NaN

# %% [markdown]
# **Impervious Surfaces**

# %%
imp_surf = pd.read_excel('data/Climate_Vulnerability_Metric_Indicators/BRACE_ImperviousSurfaces_423_CT_PL_CO_RE_CA.xlsx', sheet_name=None)
 
# collect Clim. Vuln. Factor sheet names
imp_surf_sheetnames = list(imp_surf.keys())

# read in sheets as df
imp_surf_README = imp_surf[imp_surf_sheetnames[0]]

imp_surf_data = imp_surf[imp_surf_sheetnames[1]]

imp_surf_dict = imp_surf[imp_surf_sheetnames[2]]

imp_surf_dict
# Out:
#                                                 Name   \
# 0                                              ind_id
# 1                                      ind_definition
# 2                                          reportyear
# 3                                       race_eth_code
# 4                                       race_eth_name
# 5                                             geotype
# 6                                        geotypevalue
# 7                                             geoname
# 8                                         county_name
# 9                                         county_fips
# 10                                        region_name
# 11                                        region_code
# 12                                    strata_one_code
# 13                                    strata_one_name
# 14                                    strata_two_code
# 15                                    strata_two_name
# 16                                          numerator
# 17                                        denominator
# 18                                           estimate
# 19                                            LL_95CI
# 20                                            UL_95CI
# 21                                                 SE
# 22                                                RSE
# 23                                          CA_decile
# 24                                              CA_RR
# 25                                            version
# 26  NOTE: Blank cells indicate data is not availab...
#
#                                            Definition Type  \
# 0                     Indicator identification number    N
# 1   Indicator (full) name and definition in plain ...    T
# 2             Year(s) that the indicator was reported    T
# 3             Numeric code for a race/ethnicity group    T
# 4                        Name of race/ethnicity group    T
# 5                             Type of geographic unit    T
# 6                            Value of geographic unit    T
# 7                             Name of geographic unit    T
# 8                   Name of county that geotype is in    T
# 9              FIPS code of county that geotype is in    T
# 10                                     Name of region    T
# 11                             Numeric code of region    T
# 12  Numeric code for weight applied for calculatin...    T
# 13            Weight applied for calculating estimate    T
# 14                  Numeric code of the second strata    T
# 15                          Name of the second strata    T
# 16            Numeric value of numerator of indicator    N
# 17                Total Population in geographic unit    N
# 18  Percent of land area covered by impervious sur...    N
# 19  Lower limit of 95% confidence interval around ...    N
# 20          Upper limit of 95% confidence interval.      N
# 21  Standard error of the estimate: measure of the...    N
# 22  Relative standard error (se/estimate * 100) ex...    N
# 23  Statewide decile ranking: 'CA_decile' groups p...    N
# 24  California Ratio: ratio estimate/state estimat...    N
# 25   Date/time stamp of version of data file creation   DT
# 26                                                NaN  NaN
#
#                                                Coding
# 0                                                 423
# 1                                                 NaN
# 2                                        2011 or 2016
# 3   1=American Indian or Alaska Native; 2=Asian; 3...
# 4   AIAN=American Indian or Alaska Native; Asian; ...
# 5   CT=Census Tract; PL=Place; CD=County Subdivisi...
# 6   Census tract code (11-characters in length sta...
# 7                                                 NaN
# 8                                                 NaN
# 9                                                 NaN
# 10                                See AIR_Regions tab
# 11                                See AIR_Regions tab
# 12         1 = area-weighted, 2 = population-weighted
# 13                 area-weighted, population-weighted
# 14                                     Not Applicable
# 15                                     Not Applicable
# 16                                     Not Applicable
# 17                                                NaN
# 18                                                NaN
# 19                                                NaN
# 20                                                NaN
# 21                                                NaN
# 22                                                NaN
# 23                                                NaN
# 24                                                NaN
# 25                                mm/DD/CCYY hh:mm:ss
# 26                                                NaN

# %% [markdown]
# **Ozone**

# %%
ozone = pd.read_excel('data/Climate_Vulnerability_Metric_Indicators/BRACE_Ozone_801_CT_PL_CO_RE_CA.XLSX', sheet_name=None)
 
# collect Clim. Vuln. Factor sheet names
ozone_sheetnames = list(ozone.keys())

# read in sheets as df
ozone_README = ozone[ozone_sheetnames[0]]

ozone_data = ozone[ozone_sheetnames[1]]

ozone_dict = ozone[ozone_sheetnames[2]]

ozone_dict
# Out:
# /Users/sofiaingersoll/anaconda3/envs/eds-env/lib/python3.11/site-packages/openpyxl/worksheet/header_footer.py:48: UserWarning: Cannot parse header or footer so it will be ignored
#   warn("""Cannot parse header or footer so it will be ignored""")
#                                                 Name   \
# 0                                              ind_id
# 1                                      ind_definition
# 2                                          reportyear
# 3                                       race_eth_code
# 4                                       race_eth_name
# 5                                             geotype
# 6                                        geotypevalue
# 7                                             geoname
# 8                                         county_name
# 9                                         county_fips
# 10                                        region_name
# 11                                        region_code
# 12                                    strata_one_code
# 13                                    strata_one_name
# 14                                    strata_two_code
# 15                                    strata_two_name
# 16                                          numerator
# 17                                        denominator
# 18                                           estimate
# 19                                            LL_95CI
# 20                                            UL_95CI
# 21                                                 SE
# 22                                                RSE
# 23                                          CA_decile
# 24                                              CA_RR
# 25                                            version
# 26  NOTE: Blank cells indicate data is not availab...
#
#                                            Definition Type  \
# 0                     Indicator identification number    N
# 1   Indicator (full) name and definition in plain ...    T
# 2             Year(s) that the indicator was reported    T
# 3             Numeric code for a race/ethnicity group    T
# 4                        Name of race/ethnicity group    T
# 5                             Type of geographic unit    T
# 6                            Value of geographic unit    T
# 7                             Name of geographic unit    T
# 8                   Name of county that geotype is in    T
# 9              FIPS code of county that geotype is in    T
# 10                                     Name of region    T
# 11                             Numeric code of region    T
# 12                   Numeric code of the first strata    T
# 13                           Name of the first strata    T
# 14                  Numeric code of the second strata    T
# 15                          Name of the second strata    T
# 16            Numeric value of numerator of indicator    N
# 17                Total Population in geographic unit    N
# 18          Three-year ozone concentration exceedance    N
# 19  Lower limit of 95% confidence interval around ...    N
# 20          Upper limit of 95% confidence interval.      N
# 21  Standard error of the estimate: measure of the...    N
# 22  Relative standard error (se/estimate * 100) ex...    N
# 23  Statewide decile ranking: 'CA_decile' groups p...    N
# 24  California Ratio: ratio estimate/state estimat...    N
# 25   Date/time stamp of version of data file creation   DT
# 26                                                NaN  NaN
#
#                                                Coding
# 0                                                 801
# 1                                                 NaN
# 2                                           2012-2014
# 3   1=American Indian or Alaska Native; 2=Asian; 3...
# 4   AIAN=American Indian or Alaska Native; Asian; ...
# 5   CT=Census Tract; CO= County; RE=Adaptation Imp...
# 6   Census tract code (11-characters in length sta...
# 7                                                 NaN
# 8                                                 NaN
# 9                                                 NaN
# 10                                See AIR_Regions tab
# 11                                See AIR_Regions tab
# 12                                                NaN
# 13                                                NaN
# 14                                                NaN
# 15                                                NaN
# 16                                     Not Applicable
# 17                                                NaN
# 18                                                NaN
# 19                                     Not Applicable
# 20                                     Not Applicable
# 21                                     Not Applicable
# 22                                     Not Applicable
# 23                                                NaN
# 24                                                NaN
# 25                                mm/DD/CCYY hh:mm:ss
# 26                                                NaN

# %% [markdown]
# **PM25 Levels**

# %%
pm25 = pd.read_excel('data/Climate_Vulnerability_Metric_Indicators/BRACE_PM25levels_776_CT_PL_CO_RE_CA.XLSX', sheet_name=None)
 
# collect Clim. Vuln. Factor sheet names
pm25_sheetnames = list(pm25.keys())

# read in sheets as df
pm25_README = pm25[pm25_sheetnames[0]]

pm25_data = pm25[pm25_sheetnames[1]]

pm25_dict = pm25[pm25_sheetnames[2]]

pm25_dict
# Out:
#                                                 Name   \
# 0                                              ind_id
# 1                                      ind_definition
# 2                                          reportyear
# 3                                       race_eth_code
# 4                                       race_eth_name
# 5                                             geotype
# 6                                        geotypevalue
# 7                                             geoname
# 8                                         county_name
# 9                                         county_fips
# 10                                        region_name
# 11                                        region_code
# 12                                    strata_one_code
# 13                                    strata_one_name
# 14                                    strata_two_code
# 15                                    strata_two_name
# 16                                          numerator
# 17                                        denominator
# 18                                           estimate
# 19                                            LL_95CI
# 20                                            UL_95CI
# 21                                                 SE
# 22                                                RSE
# 23                                          CA_decile
# 24                                              CA_RR
# 25                                            version
# 26  NOTE: Blank cells indicate data is not availab...
#
#                                            Definition Type  \
# 0                     Indicator identification number    N
# 1   Indicator (full) name and definition in plain ...    T
# 2             Year(s) that the indicator was reported    T
# 3             Numeric code for a race/ethnicity group    T
# 4                        Name of race/ethnicity group    T
# 5                             Type of geographic unit    T
# 6                            Value of geographic unit    T
# 7                             Name of geographic unit    T
# 8                   Name of county that geotype is in    T
# 9              FIPS code of county that geotype is in    T
# 10                                     Name of region    T
# 11                             Numeric code of region    T
# 12                   Numeric code of the first strata    T
# 13                           Name of the first strata    T
# 14                  Numeric code of the second strata    T
# 15                          Name of the second strata    T
# 16            Numeric value of numerator of indicator    N
# 17                Total Population in geographic unit    N
# 18  Annual mean concentration of PM2.5 (average qu...    N
# 19  Lower limit of 95% confidence interval around ...    N
# 20          Upper limit of 95% confidence interval.      N
# 21  Standard error of the estimate: measure of the...    N
# 22  Relative standard error (se/estimate * 100) ex...    N
# 23  Statewide decile ranking: 'CA_decile' groups p...    N
# 24  California Ratio: ratio estimate/state estimat...    N
# 25   Date/time stamp of version of data file creation   DT
# 26                                                NaN  NaN
#
#                                                Coding
# 0                                                 776
# 1                                                 NaN
# 2                                2009-2011, 2012-2014
# 3   1=American Indian or Alaska Native; 2=Asian; 3...
# 4   AIAN=American Indian or Alaska Native; Asian; ...
# 5   CT=Census Tract; PL=Place; CD=County Subdivisi...
# 6   Census tract code (11-characters in length sta...
# 7                                                 NaN
# 8                                                 NaN
# 9                                                 NaN
# 10                                See AIR_Regions tab
# 11                                See AIR_Regions tab
# 12                                                NaN
# 13                                                NaN
# 14                                                NaN
# 15                                                NaN
# 16                                     Not Applicable
# 17                                                NaN
# 18                                                NaN
# 19                                     Not Applicable
# 20                                     Not Applicable
# 21                                     Not Applicable
# 22                                     Not Applicable
# 23                                                NaN
# 24                                                NaN
# 25                                mm/DD/CCYY hh:mm:ss
# 26                                                NaN

# %% [markdown]
# **Sea Level Rise (SRL)**

# %%
slr = pd.read_excel('data/Climate_Vulnerability_Metric_Indicators/BRACE_SLR_784_CT_PL_CO_RE_CA_11-1-2016.xlsx', sheet_name=None)
 
# collect Clim. Vuln. Factor sheet names
slr_sheetnames = list(slr.keys())

# read in sheets as df
slr_README = slr[slr_sheetnames[0]]

slr_data = slr[slr_sheetnames[1]]

slr_dict = slr[slr_sheetnames[2]]

slr_dict
# Out:
#                                                 Name   \
# 0                                              ind_id
# 1                                      ind_definition
# 2                                          reportyear
# 3                                       race_eth_code
# 4                                       race_eth_name
# 5                                             geotype
# 6                                        geotypevalue
# 7                                             geoname
# 8                                         county_name
# 9                                         county_fips
# 10                                        region_name
# 11                                        region_code
# 12                                    strata_one_code
# 13                                    strata_one_name
# 14                                    strata_two_code
# 15                                    strata_two_name
# 16                                          numerator
# 17                                        denominator
# 18                                           estimate
# 19                                            LL_95CI
# 20                                            UL_95CI
# 21                                                 SE
# 22                                                RSE
# 23                                          CA_decile
# 24                                              CA_RR
# 25                                            version
# 26  NOTE: Blank cells indicate data is not availab...
#
#                                            Definition Type  \
# 0                     Indicator identification number    N
# 1   Indicator (full) name and definition in plain ...    T
# 2             Year(s) that the indicator was reported    T
# 3             Numeric code for a race/ethnicity group    T
# 4                        Name of race/ethnicity group    T
# 5                             Type of geographic unit    T
# 6                            Value of geographic unit    T
# 7                             Name of geographic unit    T
# 8                   Name of county that geotype is in    T
# 9              FIPS code of county that geotype is in    T
# 10                                     Name of region    T
# 11                             Numeric code of region    T
# 12                   Numeric code of the first strata    T
# 13                           Name of the first strata    T
# 14                  Numeric code of the second strata    T
# 15                          Name of the second strata    T
# 16            Numeric value of numerator of indicator    N
# 17                Total Population in geographic unit    N
# 18  Percent of population living in sea level rise...    N
# 19  Lower limit of 95% confidence interval around ...    N
# 20          Upper limit of 95% confidence interval.      N
# 21  Standard error of the estimate: measure of the...    N
# 22  Relative standard error (se/estimate * 100) ex...    N
# 23  Statewide decile ranking: 'CA_decile' groups p...    N
# 24  California Ratio: ratio estimate/state estimat...    N
# 25   Date/time stamp of version of data file creation   DT
# 26                                                NaN  NaN
#
#                                                Coding
# 0                                                 784
# 1                                                 NaN
# 2                                                2009
# 3   1=American Indian or Alaska Native; 2=Asian; 3...
# 4   AIAN=American Indian or Alaska Native; Asian; ...
# 5   CT=Census Tract; PL=Place; CD=County Subdivisi...
# 6   Census tract code (11-characters in length sta...
# 7                                                 NaN
# 8                                                 NaN
# 9                                                 NaN
# 10                                See AIR_Regions tab
# 11                                See AIR_Regions tab
# 12                                     Not Applicable
# 13                                     Not Applicable
# 14                                     Not Applicable
# 15                                     Not Applicable
# 16                                                NaN
# 17                                                NaN
# 18                                                NaN
# 19                                                NaN
# 20                                                NaN
# 21                                                NaN
# 22                                                NaN
# 23                                                NaN
# 24                                                NaN
# 25                                mm/DD/CCYY hh:mm:ss
# 26                                                NaN

# %% [markdown]
# **Tree Canopy**

# %%
tree_canopy = pd.read_excel('data/Climate_Vulnerability_Metric_Indicators/BRACE_TreeCanopy_458_CT_PL_CO_RE_CA.xlsx', sheet_name=None)
 
# collect Clim. Vuln. Factor sheet names
tree_canopy_sheetnames = list(tree_canopy.keys())

# read in sheets as df
tree_canopy_README = tree_canopy[tree_canopy_sheetnames[0]]

tree_canopy_data = tree_canopy[tree_canopy_sheetnames[1]]

tree_canopy_dict = tree_canopy[tree_canopy_sheetnames[2]]

tree_canopy_dict
# Out:
#                                                 Name   \
# 0                                              ind_id
# 1                                      ind_definition
# 2                                          reportyear
# 3                                       race_eth_code
# 4                                       race_eth_name
# 5                                             geotype
# 6                                        geotypevalue
# 7                                             geoname
# 8                                         county_name
# 9                                         county_fips
# 10                                        region_name
# 11                                        region_code
# 12                                    strata_one_code
# 13                                    strata_one_name
# 14                                    strata_two_code
# 15                                    strata_two_name
# 16                                          numerator
# 17                                        denominator
# 18                                           estimate
# 19                                            LL_95CI
# 20                                            UL_95CI
# 21                                                 SE
# 22                                                RSE
# 23                                          CA_decile
# 24                                              CA_RR
# 25                                            version
# 26  NOTE: Blank cells indicate data is not availab...
#
#                                            Definition Type  \
# 0                     Indicator identification number    N
# 1   Indicator (full) name and definition in plain ...    T
# 2             Year(s) that the indicator was reported    T
# 3             Numeric code for a race/ethnicity group    T
# 4                        Name of race/ethnicity group    T
# 5                             Type of geographic unit    T
# 6                            Value of geographic unit    T
# 7                             Name of geographic unit    T
# 8                   Name of county that geotype is in    T
# 9              FIPS code of county that geotype is in    T
# 10                                     Name of region    T
# 11                             Numeric code of region    T
# 12  Numeric code for weight applied for calculatin...    T
# 13            Weight applied for calculating estimate    T
# 14                  Numeric code of the second strata    T
# 15                          Name of the second strata    T
# 16            Numeric value of numerator of indicator    N
# 17                Total Population in geographic unit    N
# 18         Percent of area not covered by tree canopy    N
# 19  Lower limit of 95% confidence interval around ...    N
# 20          Upper limit of 95% confidence interval.      N
# 21  Standard error of the estimate: measure of the...    N
# 22  Relative standard error (se/estimate * 100) ex...    N
# 23  Statewide decile ranking: 'CA_decile' groups p...    N
# 24  California Ratio: ratio estimate/state estimat...    N
# 25   Date/time stamp of version of data file creation   DT
# 26                                                NaN  NaN
#
#                                                Coding
# 0                                                 458
# 1                                                 NaN
# 2                                                2011
# 3   1=American Indian or Alaska Native; 2=Asian; 3...
# 4   AIAN=American Indian or Alaska Native; Asian; ...
# 5   CT=Census Tract; PL=Place; CD=County Subdivisi...
# 6   Census tract code (11-characters in length sta...
# 7                                                 NaN
# 8                                                 NaN
# 9                                                 NaN
# 10                                See AIR_Regions tab
# 11                                See AIR_Regions tab
# 12         1 = area-weighted, 2 = population-weighted
# 13                 area-weighted, population-weighted
# 14                                     Not Applicable
# 15                                     Not Applicable
# 16                                     Not Applicable
# 17                                                NaN
# 18                                                NaN
# 19                                                NaN
# 20                                                NaN
# 21                                                NaN
# 22                                                NaN
# 23                                                NaN
# 24                                                NaN
# 25                                mm/DD/CCYY hh:mm:ss
# 26                                                NaN

# %% [markdown]
# **Wildfire**

# %%
wildfire = pd.read_excel('data/Climate_Vulnerability_Metric_Indicators/BRACE_Wildfire_786_CT_PL_CO_RE_CA.xlsx', sheet_name=None)
 
# collect Clim. Vuln. Factor sheet names
wildfire_sheetnames = list(wildfire.keys())

# read in sheets as df
wildfire_README = wildfire[wildfire_sheetnames[0]]

wildfire_data = wildfire[wildfire_sheetnames[1]]

wildfire_dict = wildfire[wildfire_sheetnames[2]]

wildfire_dict
# Out:
#                                                 Name   \
# 0                                              ind_id
# 1                                      ind_definition
# 2                                          reportyear
# 3                                       race_eth_code
# 4                                       race_eth_name
# 5                                             geotype
# 6                                        geotypevalue
# 7                                             geoname
# 8                                         county_name
# 9                                         county_fips
# 10                                        region_name
# 11                                        region_code
# 12                                    strata_one_code
# 13                                    strata_one_name
# 14                                    strata_two_code
# 15                                    strata_two_name
# 16                                          numerator
# 17                                        denominator
# 18                                           estimate
# 19                                            LL_95CI
# 20                                            UL_95CI
# 21                                                 SE
# 22                                                RSE
# 23                                          CA_decile
# 24                                              CA_RR
# 25                                            version
# 26  NOTE: Blank cells indicate data is not availab...
#
#                                            Definition Type  \
# 0                     Indicator identification number    N
# 1   Indicator (full) name and definition in plain ...    T
# 2             Year(s) that the indicator was reported    T
# 3             Numeric code for a race/ethnicity group    T
# 4                        Name of race/ethnicity group    T
# 5                             Type of geographic unit    T
# 6                            Value of geographic unit    T
# 7                             Name of geographic unit    T
# 8                   Name of county that geotype is in    T
# 9              FIPS code of county that geotype is in    T
# 10                                     Name of region    T
# 11                             Numeric code of region    T
# 12                   Numeric code of the first strata    T
# 13                           Name of the first strata    T
# 14                  Numeric code of the second strata    T
# 15                          Name of the second strata    T
# 16            Numeric value of numerator of indicator    N
# 17                Total Population in geographic unit    N
# 18  Percent of population living in very high wild...    N
# 19  Lower limit of 95% confidence interval around ...    N
# 20          Upper limit of 95% confidence interval.      N
# 21  Standard error of the estimate: measure of the...    N
# 22  Relative standard error (se/estimate * 100) ex...    N
# 23  Statewide decile ranking: 'CA_decile' groups p...    N
# 24  California Ratio: ratio estimate/state estimat...    N
# 25   Date/time stamp of version of data file creation   DT
# 26                                                NaN  NaN
#
#                                                Coding
# 0                                                 786
# 1                                                 NaN
# 2                                                2007
# 3   1=American Indian or Alaska Native; 2=Asian; 3...
# 4   AIAN=American Indian or Alaska Native; Asian; ...
# 5   CT=Census Tract; PL=Place; CD=County Subdivisi...
# 6   Census tract code (11-characters in length sta...
# 7                                                 NaN
# 8                                                 NaN
# 9                                                 NaN
# 10                                See AIR_Regions tab
# 11                                See AIR_Regions tab
# 12                                     Not Applicable
# 13                                     Not Applicable
# 14                                     Not Applicable
# 15                                     Not Applicable
# 16                                                NaN
# 17                                                NaN
# 18                                                NaN
# 19                                                NaN
# 20                                                NaN
# 21                                                NaN
# 22                                                NaN
# 23                                                NaN
# 24                                                NaN
# 25                                mm/DD/CCYY hh:mm:ss
# 26                                                NaN

# %% [markdown]
# **Drought**

# %%
# load drought metric NETCDF data
# fabulous, it contains geolocation data
# let's merge this with the combo metric data and see how it plots
folder = 'data/Climate_Vulnerability_Metric_Indicators/'
drought_path = os.path.join(folder, 'pdsi_current_PRISM.nc')

drought = xr.open_dataset(drought_path)
drought_df = drought.to_dataframe()

# okay lat/long are indexes, this is an issue for combining
drought_df = drought_df.reset_index()
drought_df.head(3)

# mental note to check later: how is day going to influence the join?
# i think should be fine bc of year vs day but there's no way of matching the og planned columns to this df
# need to make a db schema to visualize how i can relate these df properly
# going to just go through the hairy wkflw for now and correct these errors tomorrow
# Out:
#     longitude   latitude        day  data
# 0 -125.020836  24.062500 2024-06-15   NaN
# 1 -125.020836  24.104166 2024-06-15   NaN
# 2 -125.020836  24.145834 2024-06-15   NaN

# %% [markdown]
# ### Social

# %% [markdown]
# **Car Ownership**

# %%
own_car = pd.read_excel('data/Climate_Vulnerability_Metric_Indicators/BRACE_CarOwnership_37_CT_PL_CO_RE_CA.XLSX', sheet_name=None)
 
# collect Clim. Vuln. Factor sheet names
own_car_sheetnames = list(own_car.keys())

# read in sheets as df
own_car_README = own_car[own_car_sheetnames[0]]

own_car_data = own_car[own_car_sheetnames[1]]

own_car_dict = own_car[own_car_sheetnames[2]]

own_car_dict
# Out:
#                                                 Name   \
# 0                                              ind_id
# 1                                      ind_definition
# 2                                          reportyear
# 3                                       race_eth_code
# 4                                       race_eth_name
# 5                                             geotype
# 6                                        geotypevalue
# 7                                             geoname
# 8                                         county_name
# 9                                         county_fips
# 10                                        region_name
# 11                                        region_code
# 12                                    strata_one_code
# 13                                    strata_one_name
# 14                                    strata_two_code
# 15                                    strata_two_name
# 16                                          numerator
# 17                                        denominator
# 18                                           estimate
# 19                                            LL_95CI
# 20                                            UL_95CI
# 21                                                 SE
# 22                                                RSE
# 23                                          CA_decile
# 24                                              CA_RR
# 25                                            version
# 26  NOTE: Blank cells indicate data is not availab...
#
#                                            Definition Type  \
# 0                     Indicator identification number    N
# 1   Indicator (full) name and definition in plain ...    T
# 2             Year(s) that the indicator was reported    T
# 3             Numeric code for a race/ethnicity group    T
# 4                        Name of race/ethnicity group    T
# 5                             Type of geographic unit    T
# 6                            Value of geographic unit    T
# 7                             Name of geographic unit    T
# 8                   Name of county that geotype is in    T
# 9              FIPS code of county that geotype is in    T
# 10                                     Name of region    T
# 11                             Numeric code of region    T
# 12                   Numeric code of the first strata    T
# 13                           Name of the first strata    T
# 14                  Numeric code of the second strata    T
# 15                          Name of the second strata    T
# 16            Numeric value of numerator of indicator    N
# 17                Total Population in geographic unit    N
# 18    Percent of households with no vehicle ownership    N
# 19  Lower limit of 95% confidence interval around ...    N
# 20          Upper limit of 95% confidence interval.      N
# 21  Standard error of the estimate: measure of the...    N
# 22  Relative standard error (se/estimate * 100) ex...    N
# 23  Statewide decile ranking: 'CA_decile' groups p...    N
# 24  California Ratio: ratio estimate/state estimat...    N
# 25   Date/time stamp of version of data file creation   DT
# 26                                                NaN  NaN
#
#                                                Coding
# 0                                                  37
# 1                                                 NaN
# 2                              2006-2010 or 2011-2015
# 3   1=American Indian or Alaska Native; 2=Asian; 3...
# 4   AIAN=American Indian or Alaska Native; Asian; ...
# 5   CT=Census Tract; PL=Place; CD=County Subdivisi...
# 6   Census tract code (11-characters in length sta...
# 7                                                 NaN
# 8                                                 NaN
# 9                                                 NaN
# 10                                See AIR_Regions tab
# 11                                See AIR_Regions tab
# 12                                     Not Applicable
# 13                                     Not Applicable
# 14                                     Not Applicable
# 15                                     Not Applicable
# 16                                                NaN
# 17                                                NaN
# 18                                                NaN
# 19                                                NaN
# 20                                                NaN
# 21                                                NaN
# 22                                                NaN
# 23                                                NaN
# 24                                                NaN
# 25                                mm/DD/CCYY hh:mm:ss
# 26                                                NaN

# %% [markdown]
# **Children**

# %%
children = pd.read_excel('data/Climate_Vulnerability_Metric_Indicators/BRACE_children_788_CT_PL_CO_RE_CA.XLSX', sheet_name=None)
 
# collect Clim. Vuln. Factor sheet names
children_sheetnames = list(children.keys())

# read in sheets as df
children_README = children[children_sheetnames[0]]

children_data = children[children_sheetnames[1]]

children_dict = children[children_sheetnames[2]]

children_dict
# Out:
#                                                 Name   \
# 0                                              ind_id
# 1                                      ind_definition
# 2                                          reportyear
# 3                                       race_eth_code
# 4                                       race_eth_name
# 5                                             geotype
# 6                                        geotypevalue
# 7                                             geoname
# 8                                         county_name
# 9                                         county_fips
# 10                                        region_name
# 11                                        region_code
# 12                                    strata_one_code
# 13                                    strata_one_name
# 14                                    strata_two_code
# 15                                    strata_two_name
# 16                                          numerator
# 17                                        denominator
# 18                                           estimate
# 19                                            LL_95CI
# 20                                            UL_95CI
# 21                                                 SE
# 22                                                RSE
# 23                                          CA_decile
# 24                                              CA_RR
# 25                                            version
# 26  NOTE: Blank cells indicate data is not availab...
#
#                                            Definition Type  \
# 0                     Indicator identification number    N
# 1   Indicator (full) name and definition in plain ...    T
# 2             Year(s) that the indicator was reported    T
# 3             Numeric code for a race/ethnicity group    T
# 4                        Name of race/ethnicity group    T
# 5                             Type of geographic unit    T
# 6                            Value of geographic unit    T
# 7                             Name of geographic unit    T
# 8                   Name of county that geotype is in    T
# 9              FIPS code of county that geotype is in    T
# 10                                     Name of region    T
# 11                             Numeric code of region    T
# 12                   Numeric code of the first strata    T
# 13                           Name of the first strata    T
# 14                  Numeric code of the second strata    T
# 15                          Name of the second strata    T
# 16            Numeric value of numerator of indicator    N
# 17                Total Population in geographic unit    N
# 18                    Percent of population < 5 years    N
# 19  Lower limit of 95% confidence interval around ...    N
# 20          Upper limit of 95% confidence interval.      N
# 21  Standard error of the estimate: measure of the...    N
# 22  Relative standard error (se/estimate * 100) ex...    N
# 23  Statewide decile ranking: 'CA_decile' groups p...    N
# 24  California Ratio: ratio estimate/state estimat...    N
# 25   Date/time stamp of version of data file creation   DT
# 26                                                NaN  NaN
#
#                                                Coding
# 0                                                 788
# 1                                                 NaN
# 2                                   2010 or 2011-2015
# 3   1=American Indian or Alaska Native; 2=Asian; 3...
# 4   AIAN=American Indian or Alaska Native; Asian; ...
# 5   CT=Census Tract; PL=Place; CD=County Subdivisi...
# 6   Census tract code (11-characters in length sta...
# 7                                                 NaN
# 8                                                 NaN
# 9                                                 NaN
# 10                                See AIR_Regions tab
# 11                                See AIR_Regions tab
# 12                                     Not Applicable
# 13                                     Not Applicable
# 14                                     Not Applicable
# 15                                     Not Applicable
# 16                                                NaN
# 17                                                NaN
# 18                                                NaN
# 19   Available for ACS data, but not 2010 Census data
# 20   Available for ACS data, but not 2010 Census data
# 21   Available for ACS data, but not 2010 Census data
# 22   Available for ACS data, but not 2010 Census data
# 23                                                NaN
# 24                                                NaN
# 25                                mm/DD/CCYY hh:mm:ss
# 26                                                NaN

# %% [markdown]
# **Disabled**

# %%
disabled = pd.read_excel('data/Climate_Vulnerability_Metric_Indicators/BRACE_Disability_795_CT_PL_CO_RE_CA.XLSX', sheet_name=None)
 
# collect Clim. Vuln. Factor sheet names
disabled_sheetnames = list(disabled.keys())

# read in sheets as df
disabled_README = disabled[disabled_sheetnames[0]]

disabled_data = disabled[disabled_sheetnames[1]]

disabled_dict = disabled[disabled_sheetnames[2]]

disabled_dict
# Out:
#                                                 Name   \
# 0                                              ind_id
# 1                                      ind_definition
# 2                                          reportyear
# 3                                       race_eth_code
# 4                                       race_eth_name
# 5                                             geotype
# 6                                        geotypevalue
# 7                                             geoname
# 8                                         county_name
# 9                                         county_fips
# 10                                        region_name
# 11                                        region_code
# 12                                    strata_one_code
# 13                                    strata_one_name
# 14                                    strata_two_code
# 15                                    strata_two_name
# 16                                          numerator
# 17                                        denominator
# 18                                           estimate
# 19                                            LL_95CI
# 20                                            UL_95CI
# 21                                                 SE
# 22                                                RSE
# 23                                          CA_decile
# 24                                              CA_RR
# 25                                            version
# 26  NOTE: Blank cells indicate data is not availab...
#
#                                            Definition Type  \
# 0                     Indicator identification number    N
# 1   Indicator (full) name and definition in plain ...    T
# 2             Year(s) that the indicator was reported    T
# 3             Numeric code for a race/ethnicity group    T
# 4                        Name of race/ethnicity group    T
# 5                             Type of geographic unit    T
# 6                            Value of geographic unit    T
# 7                             Name of geographic unit    T
# 8                   Name of county that geotype is in    T
# 9              FIPS code of county that geotype is in    T
# 10                                     Name of region    T
# 11                             Numeric code of region    T
# 12                Numeric code for type of disability    T
# 13                                 Type of disability    T
# 14                  Numeric code of the second strata    T
# 15                          Name of the second strata    T
# 16            Numeric value of numerator of indicator    N
# 17                Total Population in geographic unit    N
# 18            Percent of population with a disability    N
# 19  Lower limit of 95% confidence interval around ...    N
# 20          Upper limit of 95% confidence interval.      N
# 21  Standard error of the estimate: measure of the...    N
# 22  Relative standard error (se/estimate * 100) ex...    N
# 23  Statewide decile ranking: 'CA_decile' groups p...    N
# 24  California Ratio: ratio estimate/state estimat...    N
# 25   Date/time stamp of version of data file creation   DT
# 26                                                NaN  NaN
#
#                                                Coding
# 0                                                 795
# 1                                                 NaN
# 2                              2008-2012 or 2011-2015
# 3   1=American Indian or Alaska Native; 2=Asian; 3...
# 4   AIAN=American Indian or Alaska Native; Asian; ...
# 5   CT=Census Tract; PL=Place; CD=County Subdivisi...
# 6   Census tract code (11-characters in length sta...
# 7                                                 NaN
# 8                                                 NaN
# 9                                                 NaN
# 10                                See AIR_Regions tab
# 11                                See AIR_Regions tab
# 12                                                NaN
# 13                            Total, Physical, Mental
# 14                                     Not Applicable
# 15                                     Not Applicable
# 16                                                NaN
# 17                                                NaN
# 18                                                NaN
# 19                                                NaN
# 20                                                NaN
# 21                                                NaN
# 22                                                NaN
# 23                                                NaN
# 24                                                NaN
# 25                                mm/DD/CCYY hh:mm:ss
# 26                                                NaN

# %% [markdown]
# **Elderly Over 65**

# %%
elderly = pd.read_excel('data/Climate_Vulnerability_Metric_Indicators/BRACE_elderly65over_789_CT_PL_CO_RE_CA.XLSX', sheet_name=None)
 
# collect Clim. Vuln. Factor sheet names
elderly_sheetnames = list(elderly.keys())

# read in sheets as df
elderly_README = elderly[elderly_sheetnames[0]]

elderly_data = elderly[elderly_sheetnames[1]]

elderly_dict = elderly[elderly_sheetnames[2]]

elderly_dict
# Out:
#                                                 Name   \
# 0                                              ind_id
# 1                                      ind_definition
# 2                                          reportyear
# 3                                       race_eth_code
# 4                                       race_eth_name
# 5                                             geotype
# 6                                        geotypevalue
# 7                                             geoname
# 8                                         county_name
# 9                                         county_fips
# 10                                        region_name
# 11                                        region_code
# 12                                    strata_one_code
# 13                                    strata_one_name
# 14                                    strata_two_code
# 15                                    strata_two_name
# 16                                          numerator
# 17                                        denominator
# 18                                           estimate
# 19                                            LL_95CI
# 20                                            UL_95CI
# 21                                                 SE
# 22                                                RSE
# 23                                          CA_decile
# 24                                              CA_RR
# 25                                            version
# 26  NOTE: Blank cells indicate data is not availab...
#
#                                            Definition Type  \
# 0                     Indicator identification number    N
# 1   Indicator (full) name and definition in plain ...    T
# 2             Year(s) that the indicator was reported    T
# 3             Numeric code for a race/ethnicity group    T
# 4                        Name of race/ethnicity group    T
# 5                             Type of geographic unit    T
# 6                            Value of geographic unit    T
# 7                             Name of geographic unit    T
# 8                   Name of county that geotype is in    T
# 9              FIPS code of county that geotype is in    T
# 10                                     Name of region    T
# 11                             Numeric code of region    T
# 12                   Numeric code of the first strata    T
# 13                           Name of the first strata    T
# 14                  Numeric code of the second strata    T
# 15                          Name of the second strata    T
# 16            Numeric value of numerator of indicator    N
# 17                Total Population in geographic unit    N
# 18                    Percent of population> 65 years    N
# 19  Lower limit of 95% confidence interval around ...    N
# 20          Upper limit of 95% confidence interval.      N
# 21  Standard error of the estimate: measure of the...    N
# 22  Relative standard error (se/estimate * 100) ex...    N
# 23  Statewide decile ranking: 'CA_decile' groups p...    N
# 24  California Ratio: ratio estimate/state estimat...    N
# 25   Date/time stamp of version of data file creation   DT
# 26                                                NaN  NaN
#
#                                                Coding
# 0                                                 789
# 1                                                 NaN
# 2                                   2010 or 2011-2015
# 3   1=American Indian or Alaska Native; 2=Asian; 3...
# 4   AIAN=American Indian or Alaska Native; Asian; ...
# 5   CT=Census Tract; PL=Place; CD=County Subdivisi...
# 6   Census tract code (11-characters in length sta...
# 7                                                 NaN
# 8                                                 NaN
# 9                                                 NaN
# 10                                See AIR_Regions tab
# 11                                See AIR_Regions tab
# 12                                     Not Applicable
# 13                                     Not Applicable
# 14                                     Not Applicable
# 15                                     Not Applicable
# 16                                                NaN
# 17                                                NaN
# 18                                                NaN
# 19   Available for ACS data, but not 2010 Census data
# 20   Available for ACS data, but not 2010 Census data
# 21   Available for ACS data, but not 2010 Census data
# 22   Available for ACS data, but not 2010 Census data
# 23                                                NaN
# 24                                                NaN
# 25                                mm/DD/CCYY hh:mm:ss
# 26                                                NaN

# %% [markdown]
# **Linguistic Isolation**

# %%
ling_isolation = pd.read_excel('data/Climate_Vulnerability_Metric_Indicators/BRACE_LinguisticIsolation_800_CT_PL_CO_RE_CA.XLSX', sheet_name=None)
 
# collect Clim. Vuln. Factor sheet names
ling_isolation_sheetnames = list(ling_isolation.keys())

# read in sheets as df
ling_isolation_README = ling_isolation[ling_isolation_sheetnames[0]]

ling_isolation_data = ling_isolation[ling_isolation_sheetnames[1]]

ling_isolation_dict = ling_isolation[ling_isolation_sheetnames[2]]

ling_isolation_dict
# Out:
#                                                 Name   \
# 0                                              ind_id
# 1                                      ind_definition
# 2                                          reportyear
# 3                                       race_eth_code
# 4                                       race_eth_name
# 5                                             geotype
# 6                                        geotypevalue
# 7                                             geoname
# 8                                         county_name
# 9                                         county_fips
# 10                                        region_name
# 11                                        region_code
# 12                                    strata_one_code
# 13                                    strata_one_name
# 14                                    strata_two_code
# 15                                    strata_two_name
# 16                                          numerator
# 17                                        denominator
# 18                                           estimate
# 19                                            LL_95CI
# 20                                            UL_95CI
# 21                                                 SE
# 22                                                RSE
# 23                                          CA_decile
# 24                                              CA_RR
# 25                                            version
# 26  NOTE: Blank cells indicate data is not availab...
#
#                                            Definition Type  \
# 0                     Indicator identification number    N
# 1   Indicator (full) name and definition in plain ...    T
# 2             Year(s) that the indicator was reported    T
# 3             Numeric code for a race/ethnicity group    T
# 4                        Name of race/ethnicity group    T
# 5                             Type of geographic unit    T
# 6                            Value of geographic unit    T
# 7                             Name of geographic unit    T
# 8                   Name of county that geotype is in    T
# 9              FIPS code of county that geotype is in    T
# 10                                     Name of region    T
# 11                             Numeric code of region    T
# 12                   Numeric code of the first strata    T
# 13                           Name of the first strata    T
# 14                  Numeric code of the second strata    T
# 15                          Name of the second strata    T
# 16            Numeric value of numerator of indicator    N
# 17                Total Population in geographic unit    N
# 18  Total Percent of households with no one aged >...    N
# 19  Lower limit of 95% confidence interval around ...    N
# 20          Upper limit of 95% confidence interval.      N
# 21  Standard error of the estimate: measure of the...    N
# 22  Relative standard error (se/estimate * 100) ex...    N
# 23  Statewide decile ranking: 'CA_decile' groups p...    N
# 24  California Ratio: ratio estimate/state estimat...    N
# 25   Date/time stamp of version of data file creation   DT
# 26                                                NaN  NaN
#
#                                                Coding
# 0                                                 800
# 1                                                 NaN
# 2                              2006-2010 or 2011-2015
# 3                                             9=Total
# 4                                               Total
# 5   CT=Census Tract; PL=Place; CD=County Subdivisi...
# 6   Census tract code (11-characters in length sta...
# 7                                                 NaN
# 8                                                 NaN
# 9                                                 NaN
# 10                                See AIR_Regions tab
# 11                                See AIR_Regions tab
# 12  Language Spoken at Home: 00 = All Non-English/...
# 13  Language Spoken at Home: All Non-English/Total...
# 14                                     Not Applicable
# 15                                     Not Applicable
# 16                                                NaN
# 17                                                NaN
# 18                                                NaN
# 19                                                NaN
# 20                                                NaN
# 21                                                NaN
# 22                                                NaN
# 23                                                NaN
# 24                                                NaN
# 25                                mm/DD/CCYY hh:mm:ss
# 26                                                NaN

# %% [markdown]
# **Outdoor Workers**

# %%
outdoor = pd.read_excel('data/Climate_Vulnerability_Metric_Indicators/BRACE_OutdoorWorkers_790_CT_PL_CO_RE_CA.XLSX', sheet_name=None)
 
# collect Clim. Vuln. Factor sheet names
outdoor_sheetnames = list(outdoor.keys())

# read in sheets as df
outdoor_README = outdoor[outdoor_sheetnames[0]]

outdoor_data = outdoor[outdoor_sheetnames[1]]

outdoor_dict = outdoor[outdoor_sheetnames[2]]

outdoor_dict
# Out:
#                                                 Name   \
# 0                                              ind_id
# 1                                      ind_definition
# 2                                          reportyear
# 3                                       race_eth_code
# 4                                       race_eth_name
# 5                                             geotype
# 6                                        geotypevalue
# 7                                             geoname
# 8                                         county_name
# 9                                         county_fips
# 10                                        region_name
# 11                                        region_code
# 12                                    strata_one_code
# 13                                    strata_one_name
# 14                                    strata_two_code
# 15                                    strata_two_name
# 16                                          numerator
# 17                                        denominator
# 18                                           estimate
# 19                                            LL_95CI
# 20                                            UL_95CI
# 21                                                 SE
# 22                                                RSE
# 23                                          CA_decile
# 24                                              CA_RR
# 25                                            version
# 26  NOTE: Blank cells indicate data is not availab...
#
#                                            Definition Type  \
# 0                     Indicator identification number    N
# 1   Indicator (full) name and definition in plain ...    T
# 2             Year(s) that the indicator was reported    T
# 3             Numeric code for a race/ethnicity group    T
# 4                        Name of race/ethnicity group    T
# 5                             Type of geographic unit    T
# 6                            Value of geographic unit    T
# 7                             Name of geographic unit    T
# 8                   Name of county that geotype is in    T
# 9              FIPS code of county that geotype is in    T
# 10                                     Name of region    T
# 11                             Numeric code of region    T
# 12                   Numeric code of the first strata    T
# 13                           Name of the first strata    T
# 14                  Numeric code of the second strata    T
# 15                          Name of the second strata    T
# 16            Numeric value of numerator of indicator    N
# 17                Total Population in geographic unit    N
# 18  Percent of population employed and > 16 years ...    N
# 19  Lower limit of 95% confidence interval around ...    N
# 20          Upper limit of 95% confidence interval.      N
# 21  Standard error of the estimate: measure of the...    N
# 22  Relative standard error (se/estimate * 100) ex...    N
# 23  Statewide decile ranking: 'CA_decile' groups p...    N
# 24  California Ratio: ratio estimate/state estimat...    N
# 25   Date/time stamp of version of data file creation   DT
# 26                                                NaN  NaN
#
#                                                Coding
# 0                                                 790
# 1                                                 NaN
# 2                              2006-2010 or 2011-2015
# 3   1=American Indian or Alaska Native; 2=Asian; 3...
# 4   AIAN=American Indian or Alaska Native; Asian; ...
# 5   CT=Census Tract; PL=Place; CD=County Subdivisi...
# 6   Census tract code (11-characters in length sta...
# 7                                                 NaN
# 8                                                 NaN
# 9                                                 NaN
# 10                                See AIR_Regions tab
# 11                                See AIR_Regions tab
# 12                                     Not Applicable
# 13                                     Not Applicable
# 14                                     Not Applicable
# 15                                     Not Applicable
# 16                                                NaN
# 17                                                NaN
# 18                                                NaN
# 19                                                NaN
# 20                                                NaN
# 21                                                NaN
# 22                                                NaN
# 23                                                NaN
# 24                                                NaN
# 25                                mm/DD/CCYY hh:mm:ss
# 26                                                NaN

# %% [markdown]
# **Race**

# %%
race = pd.read_excel('data/Climate_Vulnerability_Metric_Indicators/BRACE_race_795_CT_PL_CO_RE_CA.XLSX', sheet_name=None)
 
# collect Clim. Vuln. Factor sheet names
race_sheetnames = list(race.keys())

# read in sheets as df
race_README = race[race_sheetnames[0]]

race_data = race[race_sheetnames[1]]

race_dict = race[race_sheetnames[2]]

race_dict
# Out:
#                                                 Name   \
# 0                                              ind_id
# 1                                      ind_definition
# 2                                          reportyear
# 3                                       race_eth_code
# 4                                       race_eth_name
# 5                                             geotype
# 6                                        geotypevalue
# 7                                             geoname
# 8                                         county_name
# 9                                         county_fips
# 10                                        region_name
# 11                                        region_code
# 12                                    strata_one_code
# 13                                    strata_one_name
# 14                                    strata_two_code
# 15                                    strata_two_name
# 16                                          numerator
# 17                                        denominator
# 18                                           estimate
# 19                                            LL_95CI
# 20                                            UL_95CI
# 21                                                 SE
# 22                                                RSE
# 23                                          CA_decile
# 24                                              CA_RR
# 25                                            version
# 26  NOTE: Blank cells indicate data is not availab...
#
#                                            Definition Type  \
# 0                     Indicator identification number    N
# 1   Indicator (full) name and definition in plain ...    T
# 2             Year(s) that the indicator was reported    T
# 3             Numeric code for a race/ethnicity group    T
# 4                        Name of race/ethnicity group    T
# 5                             Type of geographic unit    T
# 6                            Value of geographic unit    T
# 7                             Name of geographic unit    T
# 8                   Name of county that geotype is in    T
# 9              FIPS code of county that geotype is in    T
# 10                                     Name of region    T
# 11                             Numeric code of region    T
# 12                   Numeric code of the first strata    T
# 13                           Name of the first strata    T
# 14                  Numeric code of the second strata    T
# 15                          Name of the second strata    T
# 16            Numeric value of numerator of indicator    N
# 17                Total Population in geographic unit    N
# 18        Percent of population by race and ethnicity    N
# 19  Lower limit of 95% confidence interval around ...    N
# 20          Upper limit of 95% confidence interval.      N
# 21  Standard error of the estimate: measure of the...    N
# 22  Relative standard error (se/estimate * 100) ex...    N
# 23  Statewide decile ranking: 'CA_decile' groups p...    N
# 24  California Ratio: ratio estimate/state estimat...    N
# 25   Date/time stamp of version of data file creation   DT
# 26                                                NaN  NaN
#
#                                                Coding
# 0                                                 794
# 1                                                 NaN
# 2                                   2010 or 2011-2015
# 3   1=American Indian or Alaska Native; 2=Asian; 3...
# 4   AIAN=American Indian or Alaska Native; Asian; ...
# 5   CT=Census Tract; PL=Place; CD=County Subdivisi...
# 6   Census tract code (11-characters in length sta...
# 7                                                 NaN
# 8                                                 NaN
# 9                                                 NaN
# 10                                See AIR_Regions tab
# 11                                See AIR_Regions tab
# 12                                     Not Applicable
# 13                                     Not Applicable
# 14                                     Not Applicable
# 15                                     Not Applicable
# 16                                                NaN
# 17                                                NaN
# 18                                                NaN
# 19   Available for ACS data, but not 2010 Census data
# 20   Available for ACS data, but not 2010 Census data
# 21   Available for ACS data, but not 2010 Census data
# 22   Available for ACS data, but not 2010 Census data
# 23                                                NaN
# 24                                                NaN
# 25                                mm/DD/CCYY hh:mm:ss
# 26                                                NaN

# %% [markdown]
# **Crime**

# %%
crime = pd.read_excel('data/Climate_Vulnerability_Metric_Indicators/HCI_Crime_752_PL_CO_RE_CA_2000-2013_21OCT15.xlsx', sheet_name=None)
 
# collect Clim. Vuln. Factor sheet names
crime_sheetnames = list(crime.keys())

# read in sheets as df
crime_README = crime[crime_sheetnames[0]]

crime_data = crime[crime_sheetnames[1]]

crime_dict = crime[crime_sheetnames[2]]

crime_dict
# Out:
#                      Name                                          Definition  \
# 0                   ind_id                                       Indicator ID
# 1           ind_definition          Definition of indicator in plain language
# 2               reportyear            Year(s) that the indicator was reported
# 3            race_eth_code            numeric code for a race/ethnicity group
# 4            race_eth_name                          Name of race/ethnic group
# 5                  geotype                            Type of geographic unit
# 6             geotypevalue                           Value of geographic unit
# 7                  geoname                            Name of geographic unit
# 8              county_fips                  Name of county that geotype is in
# 9              county_name             FIPS code of county that geotype is in
# 10             region_code                              MPO-based region name
# 11             region_name                              MPO-based region code
# 12        strata_name_code                                Code for the strata
# 13             strata_name                                 Name of the strata
# 14  strata_level_name_code                         Code for the strata levels
# 15       strata_level_name                          Nome of the strata levels
# 16               numerator                  Number of crimes by type of crime
# 17             denominator  Total population as reported by the Federal Bu...
# 18                    rate      Number of violent crimes per 1,000 population
# 19                 ll_95ci             Lower limit of 95% confidence interval
# 20                 ul_95ci             Upper limit of 95% confidence interval
# 21                      se                         Standard error of the rate
# 22                     rse  Relative standard error (se/percent * 100) exp...
# 23               ca_decile                                  California decile
# 24                   ca_rr                      Rate ratio to California rate
# 25          dof_population  Total population from the California Departmen...
# 26                 version                 Date/time stamp of version of data
#
#    Type         Width/Format  \
# 0     N                    3
# 1     T                  255
# 2     N                    4
# 3     N                    1
# 4     T                    5
# 5     T                    2
# 6     N                    5
# 7     T                   30
# 8     T                   25
# 9     T                    5
# 10    T                   30
# 11    T                    2
# 12    N                    2
# 13    T                   25
# 14    N                    2
# 15    T                   40
# 16    N         double prec.
# 17    N         double prec.
# 18    N         double prec.
# 19    N         double prec.
# 20    N         double prec.
# 21    N         double prec.
# 22    N         double prec.
# 23    N              integer
# 24   N          double prec.
# 25   N          double prec.
# 26  D/T  mm/DD/CCYY hh:mm:ss
#
#                                       Coding/Comments
# 0                                                 752
# 1                                           Free text
# 2   2000, 2001, 2002, 2003, 2004, 2005, 2006, 2007...
# 3                                             9=Total
# 4                                               Total
# 5   PL: Place (including city, town and census des...
# 6   5-digit FIPS place code, 5-digit FIPS county c...
# 7    place name, county name, region name, state name
# 8                            NA for geotype RE and CA
# 9   2-digit census state code (06) plus 3-digit ce...
# 10                            See MPO_County List Tab
# 11                            See MPO_County List Tab
# 12                            1=Type of violent crime
# 13                              Type of violent crime
# 14  1=Aggravated assault, 2=Forcible rape, 3=Murde...
# 15  Aggravated assault, Forcible rape, Murder and ...
# 16                                                NaN
# 17                                                NaN
# 18  Calculated for the "Violent crime total" strat...
# 19  Lower limit of 95% confidence interval.  The 9...
# 20          Upper limit of 95% confidence interval.
# 21  The standard error (SE) of the mean is a measu...
# 22  The relative standard error (RSE) provides the...
# 23  'ca_decile' groups places into 10 groups (or d...
# 24  Ratio of local percentage to regional rate. Th...
# 25  Source: California Department of Finance, Demo...
# 26                                                NaN

# %% [markdown]
# **Educational Attainment**

# %%
education = pd.read_excel('data/Climate_Vulnerability_Metric_Indicators/HCI_Educational_Attainment_355_CA_RE_CO_CD_PL_CT_Total2018-06-12-ADA_BH.xlsx', sheet_name=None)
 
# collect Clim. Vuln. Factor sheet names
education_sheetnames = list(education.keys())

# read in sheets as df
education_README = education[education_sheetnames[0]]

education_data = education[education_sheetnames[1]]

education_dict = education[education_sheetnames[2]]

education_dict
# Out:
#                                           COLUMN NAME  \
# 0                                              ind_id
# 1                                      ind_definition
# 2                                          reportyear
# 3                                       race_eth_code
# 4                                       race_eth_name
# 5                                             geotype
# 6                                        geotypevalue
# 7                                             geoname
# 8                                         county_name
# 9                                         county_fips
# 10                                        region_name
# 11                                        region_code
# 12                                    strata_one_code
# 13                                    strata_one_name
# 14                                    strata_two_code
# 15                                    strata_two_name
# 16                                          numerator
# 17                                        denominator
# 18                                           estimate
# 19                                            LL_95CI
# 20                                            UL_95CI
# 21                                                 SE
# 22                                                RSE
# 23                                          CA_decile
# 24                                              CA_RR
# 25                                            version
# 26  NOTE: "NA" cells indicate data is not availabl...
# 27                                   End of worksheet
#
#                                            DEFINITION                 FORMAT  \
# 0                     Indicator identification number                 String
# 1           Definition of indicator in plain language                 String
# 2             Year(s) that the indicator was reported                 String
# 3             Numeric code for a race/ethnicity group                 String
# 4                           Name of race/ethnic group                 String
# 5                             Type of geographic unit                 String
# 6                            Value of geographic unit                 String
# 7                             Name of geographic unit                 String
# 8                   Name of county that geotype is in                 String
# 9              FIPS code of county that geotype is in                 String
# 10  Metopolitan Planning Organization (MPO)-based ...                 String
# 11  Metopolitan Planning Organization (MPO)-based ...                 String
# 12                        Numeric code for strata one                 String
# 13       Strata one: place of birth of the population                 String
# 14                     Not available for this dataset                 String
# 15                     Not available for this dataset                 String
# 16  Numerator, population 25 years or older with h...  Numeric: Whole number
# 17         Denominator,  population 25 years or older  Numeric: Whole number
# 18  Percent of population age 25 and up with a fou...       Numeric: Decimal
# 19  Lower limit of 95% confidence interval around ...       Numeric: Decimal
# 20          Upper limit of 95% confidence interval.         Numeric: Decimal
# 21  Standard error of the estimate: measure of the...       Numeric: Decimal
# 22  Relative standard error (se/estimate * 100) ex...       Numeric: Decimal
# 23  Statewide decile ranking: 'CA_decile' groups p...       Numeric: Decimal
# 24  California Ratio: ratio estimate/state estimat...       Numeric: Decimal
# 25                 Date/time stamp of version of data                   Date
# 26                                                NaN                    NaN
# 27                                                NaN                    NaN
#
#                                                CODING
# 0   355; code for internal use in the Office of He...
# 1   Percent of population age 25 and up with a fou...
# 2   2000, 2006-2010, 2011-2015.  2000 data is from...
# 3   1=American Indian or Alaska Native (AIAN); 2=A...
# 4   AIAN=American Indian or Alaska Native; Asian; ...
# 5   CT=Census tract; PL=Place (includes cities, to...
# 6   Census tract code (11-characters in length sta...
# 7   census tract name, place name, county subdivis...
# 8                Not available for geotypes RE and CA
# 9   2-digit census state code (06) plus 3-digit ce...
# 10  Metropolitan Planning Organizations (MPO) regi...
# 11  01=Bay Area; 02=Butte; 03=Central/Southeast Si...
# 12  1=Born in state of residence; 2=Born in other ...
# 13  Born in state of residence; Born in other stat...
# 14                                                NaN
# 15                                                NaN
# 16                                                NaN
# 17                                                NaN
# 18  Blank cells indicate data not reported by the ...
# 19                                                NaN
# 20                                                NaN
# 21                                                NaN
# 22                                                NaN
# 23                                                NaN
# 24                                                NaN
# 25                                mm/DD/CCYY hh:mm:ss
# 26                                                NaN
# 27                                                NaN

# %% [markdown]
# **Poverty Rate**

# %%
poverty = pd.read_excel('data/Climate_Vulnerability_Metric_Indicators/HCI_PovertyRate_200FPL_754_CA_RE_CO_CD_PL_PUMA_CT_20112015_20122016_Total2018-10-01-ADA.xlsx', sheet_name=None)
 
# collect Clim. Vuln. Factor sheet names
poverty_sheetnames = list(poverty.keys())

# read in sheets as df
poverty_README = poverty[poverty_sheetnames[0]]

poverty_data = poverty[poverty_sheetnames[1]]

poverty_dict = poverty[poverty_sheetnames[2]]

poverty_dict
# Out:
#                                           COLUMN NAME  \
# 0                                              ind_id
# 1                                      ind_definition
# 2                                          reportyear
# 3                                       race_eth_code
# 4                                       race_eth_name
# 5                                             geotype
# 6                                        geotypevalue
# 7                                             geoname
# 8                                         county_name
# 9                                         county_fips
# 10                                        region_name
# 11                                        region_code
# 12                                    strata_one_code
# 13                                    strata_one_name
# 14                                    strata_two_code
# 15                                    strata_two_name
# 16                                          numerator
# 17                                        denominator
# 18                                           estimate
# 19                                            LL_95CI
# 20                                            UL_95CI
# 21                                                 SE
# 22                                                RSE
# 23                                          CA_decile
# 24                                              CA_RR
# 25                                            version
# 26  NOTE: "NA" cells indicate data is not availabl...
# 27                                   End of worksheet
#
#                                            DEFINITION                 FORMAT  \
# 0                     Indicator identification number                 String
# 1           Definition of indicator in plain language                 String
# 2             Year(s) that the indicator was reported                 String
# 3             Numeric code for a race/ethnicity group                 String
# 4                           Name of race/ethnic group                 String
# 5                             Type of geographic unit                 String
# 6                            Value of geographic unit                 String
# 7                             Name of geographic unit                 String
# 8                   Name of county that geotype is in                 String
# 9              FIPS code of county that geotype is in                 String
# 10  Metopolitan Planning Organization (MPO)-based ...                 String
# 11  Metopolitan Planning Organization (MPO)-based ...                 String
# 12                        Numeric code for strata one                 String
# 13                        Strata one: type of poverty                 String
# 14                        Numeric code for strata two                 String
# 15                                         Strata two                 String
# 16                   Numerator, population  <200% FPL  Numeric: Whole number
# 17                     Denominator,  total population  Numeric: Whole number
# 18                    Percent of population <200% FPL       Numeric: Decimal
# 19  Lower limit of 95% confidence interval around ...       Numeric: Decimal
# 20          Upper limit of 95% confidence interval.         Numeric: Decimal
# 21  Standard error of the estimate: measure of the...       Numeric: Decimal
# 22  Relative standard error (se/estimate * 100) ex...       Numeric: Decimal
# 23  Statewide decile ranking: 'CA_decile' groups p...       Numeric: Decimal
# 24  California Ratio: ratio estimate/state estimat...       Numeric: Decimal
# 25                 Date/time stamp of version of data                   Date
# 26                                                NaN                    NaN
# 27                                                NaN                    NaN
#
#                                                CODING
# 0   754; code for internal use in the Office of He...
# 1              Percent of population living <200% FPL
# 2   2011-2015 (overall poverty); 2012-2016 (child ...
# 3   1=American Indian or Alaska Native (AIAN); 2=A...
# 4   AIAN=American Indian or Alaska Native; Asian; ...
# 5   CT=Census tract; PUMA=Public Use Microdata Are...
# 6   Census tract code (11-characters in length sta...
# 7   census tract name, place name, county subdivis...
# 8         Not available for geotypes CA, RE, and PUMA
# 9   2-digit census state code (06) plus 3-digit ce...
# 10  Metropolitan Planning Organizations (MPO) regi...
# 11  01=Bay Area; 02=Butte; 03=Central/Southeast Si...
# 12                 1=child poverty; 3=overall poverty
# 13                                     Overall; child
# 14                                                NaN
# 15                                                NaN
# 16                                                NaN
# 17                                                NaN
# 18                                                NaN
# 19                                                NaN
# 20                                                NaN
# 21                                                NaN
# 22                                                NaN
# 23                                                NaN
# 24                                                NaN
# 25                                mm/DD/CCYY hh:mm:ss
# 26                                                NaN
# 27                                                NaN

# %% [markdown]
# ### Governance

# %% [markdown]
# **Insurance**

# %%
insurance = pd.read_excel('data/Climate_Vulnerability_Metric_Indicators/BRACE_Insurance_187_CT_PL_CO_RE_CA.XLSX', sheet_name=None)
 
# collect Clim. Vuln. Factor sheet names
insurance_sheetnames = list(insurance.keys())

# read in sheets as df
insurance_README = insurance[insurance_sheetnames[0]]

insurance_data = insurance[insurance_sheetnames[1]]

insurance_dict = insurance[insurance_sheetnames[2]]

insurance_dict
# Out:
#                                                 Name   \
# 0                                              ind_id
# 1                                      ind_definition
# 2                                          reportyear
# 3                                       race_eth_code
# 4                                       race_eth_name
# 5                                             geotype
# 6                                        geotypevalue
# 7                                             geoname
# 8                                         county_name
# 9                                         county_fips
# 10                                        region_name
# 11                                        region_code
# 12                                    strata_one_code
# 13                                    strata_one_name
# 14                                    strata_two_code
# 15                                    strata_two_name
# 16                                          numerator
# 17                                        denominator
# 18                                           estimate
# 19                                            LL_95CI
# 20                                            UL_95CI
# 21                                                 SE
# 22                                                RSE
# 23                                          CA_decile
# 24                                              CA_RR
# 25                                            version
# 26  NOTE: Blank cells indicate data is not availab...
#
#                                            Definition Type  \
# 0                     Indicator identification number    N
# 1   Indicator (full) name and definition in plain ...    T
# 2             Year(s) that the indicator was reported    T
# 3             Numeric code for a race/ethnicity group    T
# 4                        Name of race/ethnicity group    T
# 5                             Type of geographic unit    T
# 6                            Value of geographic unit    T
# 7                             Name of geographic unit    T
# 8                   Name of county that geotype is in    T
# 9              FIPS code of county that geotype is in    T
# 10                                     Name of region    T
# 11                             Numeric code of region    T
# 12                   Numeric code of the first strata    T
# 13                           Name of the first strata    T
# 14                  Numeric code of the second strata    T
# 15                          Name of the second strata    T
# 16            Numeric value of numerator of indicator    N
# 17                Total Population in geographic unit    N
# 18  Percent of adult population without health ins...    N
# 19  Lower limit of 95% confidence interval around ...    N
# 20          Upper limit of 95% confidence interval.      N
# 21  Standard error of the estimate: measure of the...    N
# 22  Relative standard error (se/estimate * 100) ex...    N
# 23  Statewide decile ranking: 'CA_decile' groups p...    N
# 24  California Ratio: ratio estimate/state estimat...    N
# 25   Date/time stamp of version of data file creation   DT
# 26                                                NaN  NaN
#
#                                                Coding
# 0                                                 795
# 1                                                 NaN
# 2       2009-2013, 2011-2013, 2011-2015, 2015 (alone)
# 3   1=American Indian or Alaska Native; 2=Asian; 3...
# 4   AIAN=American Indian or Alaska Native; Asian; ...
# 5   CT=Census Tract; PL=Place; CD=County Subdivisi...
# 6   Census tract code (11-characters in length sta...
# 7                                                 NaN
# 8                                                 NaN
# 9                                                 NaN
# 10                                See AIR_Regions tab
# 11                                See AIR_Regions tab
# 12                                     Not Applicable
# 13                                     Not Applicable
# 14                                     Not Applicable
# 15                                     Not Applicable
# 16                                                NaN
# 17                                                NaN
# 18                                                NaN
# 19                                                NaN
# 20                                                NaN
# 21                                                NaN
# 22                                                NaN
# 23                                                NaN
# 24                                                NaN
# 25                                mm/DD/CCYY hh:mm:ss
# 26                                                NaN
