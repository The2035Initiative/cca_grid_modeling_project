# %% [markdown]
# # Identifying Vulnerable Census Tracts for Oversampling in Electrify CA Survey
#
# Author: Sofia Ingersoll
#
# Date: 2024-06-28
#
# ##### This analysis is looking at each of these spatial datasets and understanding for each indicator where there is no overlap between them. We need to overlay the data sets and visualize (relative to the calEnviroScreen) where the data sets do not overlap. That will help us decide which census tracts or zip codes we need to include for oversampling.
#
#
# *Configuration Notes:
# eds-env is the environment I am using. Will provide full package breakdown once project is complete*

# %% [markdown]
# ### EJ datasets - our board recommended:
# - [SB535 Disadvantaged Communities](https://oehha.ca.gov/calenviroscreen/sb535)
# - [CalEnviroScreen](https://oehha.ca.gov/calenviroscreen/maps-data)
# - [San Diego Climate Equity Index](https://www.arcgis.com/home/item.html?id=859711eac76f47a7996b39a424c5c222)
# - [EJScreen Tool](https://www.epa.gov/ejscreen/download-ejscreen-data)
# - [White House Map](https://screeningtool.geoplatform.gov/en/downloads#3/33.47/-97.5)
# - [Climate & Health Vulnerability Indicators for CA (Climate Vulnerability Metric)](https://www.cdph.ca.gov/Programs/OHE/Pages/CC-Health-Vulnerability-Indicators.aspx#)
# - [DOE's Energy Justice Mapping Tool - Disadvantaged Communities Reporter (EJMT)](https://energyjustice.egs.anl.gov/)
# - [CDC's Environmental Justice Index (EJI)](https://www.atsdr.cdc.gov/placeandhealth/eji/index.html)
# - [CDC's Social Vulnerability Index (SVI)](https://www.atsdr.cdc.gov/placeandhealth/svi/index.html)
# - [US Climate Vulnerability Index: Overall Climate Vulnerability in The U.S.](https://map.climatevulnerabilityindex.org/map/cvi_overall/usa?mapBoundaries=Tract&mapFilter=0&reportBoundaries=Tract&geoContext=State)

# %% [markdown]
# ##### Data Notes
#
#  The data provided by [Climate & Health Vulnerability Indicators for CA (Climate Vulnerability Metric)](https://www.cdph.ca.gov/Programs/OHE/Pages/CC-Health-Vulnerability-Indicators.aspx#) includes the `Environmental Exposures Domain`, the `Population Sensitivty Domain`, and the `Adaptive Capacity Domain`.

# %%
# loading libraries
import os
import pandas as pd
import numpy as np
import geopandas as gpd 
import xarray as xr 
import rioxarray as rioxr
import rasterio 
import matplotlib.pyplot as plt

# Function to convert column names to snake_case
def to_snake_case(df):
    df.columns = df.columns.str.strip().str.replace(' ', '_').str.replace('\n', '_').str.lower()
    return df

# %% [markdown]
# #### Rough Game Plan
#
# ##### Quick Mapping
# - Read in the CA tract data
# - Convert everything into geospatial objects
# - Assess and identify components provided in each data set (Get familair with data)
# - Match CRS + resolution
# - Overlay maps to visualize areas without intersectionality
#
# ##### Surveying Application of Results
# - Create a xlsx of the census tracts that have zero intersection
# - Create a xlsx of the census tracts with the most overlap
#
# ##### Interpretting
# - What % of CA tracts are within the overlapping regions?
# - What is the approximate population within those regions?
# - Same questions for those regions **not** intersecting

# %% [markdown]
# ### Quick Mapping
#
# ##### Reading & Wrangling Data

# %% [markdown]
# ##### SB535 Disadvantaged Communities Data

# %%
# import SB535 Disadvantaged Communities data
sb535_filename = '../data/SB535_disadv_communities/SB535DACresultsdatadictionary_F_2022.xlsx'
#sb535 =  pd.ExcelFile(sb535_filename)

sb535 = pd.read_excel(sb535_filename, sheet_name=None)

sb535
# Out:
# {'Data dictionary':                                                                                                                          SB535 Disadvantaged Communities List (2022)  \
#  0                                                  The following tabs in this Excel file contain the list of disadvantaged communities (DACs) designated by CalEPA.
#  1                The second tab "SB 535 tract list" contains the list of census tracts identified as DACs by use of the CalEnivroScreen tool. (Data dictonary below)
#  2   The third tab "SB535 tribal area list" contains the list of tribal areas in California that are identified as DACs. (Data dictionary at the bottom of this page)
#  3                A Tribe may establish that a particular area of land is under its control, for purposes of this designation, by requesting a consultation with the
#  4                                              CalEPA Deputy Secretary for Environmental Justice, Tribal Affairs and Border Relations at TribalAffairs@calepa.ca.gov
#  ..                                                                                                                                                               ...
#  81                                                                                                                                                              Name
#  82                                                                                                                                                        Component
#  83                                                                                                                                                               NaN
#  84                                                                                                                                                               NaN
#  85                                                                                                                                                               NaN
#
#                                                                                                                                                                                                                 Unnamed: 1
#  0                                                                                                                                                                                                                     NaN
#  1                                                                                                                                                                                                                     NaN
#  2                                                                                                                                                                                                                     NaN
#  3                                                                                                                                                                                                                     NaN
#  4                                                                                                                                                                                                                     NaN
#  ..                                                                                                                                                                                                                    ...
#  81                                                                                                                                                                                      Current American Indian area name
#  82  Component type. "R" is Federally recognized American Indian Reservations (AIRs) and "T" is Off-Reservation Trust Lands (ORTL). Note: On-reservation trust lands are included as part of the reservation "R" boundary.
#  83                                                                                                                                                                                                                    NaN
#  84                                                                                                                                                                                                                    NaN
#  85
#
#  [86 rows x 2 columns],
#  'SB535 tract list (2022)':       Census Tract  CalEnviroScreen\n4.0 Score  \
#  0       6001400900                   40.706036
#  1       6001401000                   43.736745
#  2       6001401300                   43.677589
#  3       6001401400                   45.084138
#  4       6001401500                   44.528208
#  ...            ...                         ...
#  2305    6113010203                   59.833979
#  2306    6113010204                   45.326498
#  2307    6115040100                   51.760832
#  2308    6115040302                   39.382454
#  2309    6115040400                   49.196056
#
#        CalEnviroScreen\n4.0 Percentile CalEnviroScreen 4.0 \nPercentile Range  \
#  0                           76.147252                                 75-80%
#  1                           80.408472                                 80-85%
#  2                           80.345436                                 80-85%
#  3                           82.123046                                 80-85%
#  4                           81.429652                                 80-85%
#  ...                               ...                                    ...
#  2305                        95.600101               95-100% (highest scores)
#  2306                        82.312153                                 80-85%
#  2307                        89.750378                                 85-90%
#  2308                        73.903177                                 70-75%
#  2309                        87.014624                                 85-90%
#
#        Pollution Burden\nPercentile  Population Characteristics\nPercentile  \
#  0                        66.409459                               74.848714
#  1                        81.829496                               70.272315
#  2                        73.976353                               76.059002
#  3                        83.385190                               71.583459
#  4                        78.780336                               74.394856
#  ...                            ...                                     ...
#  2305                     97.473553                               79.538578
#  2306                     76.353454                               77.975290
#  2307                     95.096453                               71.293495
#  2308                     57.722464                               78.088754
#  2309                     67.691350                               91.868381
#
#        Total Population California County  Approximate Zip Code  \
#  0                 2471          Alameda                  94608
#  1                 6133          Alameda                  94608
#  2                 3921          Alameda                  94609
#  3                 4732          Alameda                  94608
#  4                 2839          Alameda                  94608
#  ...                ...               ...                   ...
#  2305              5355             Yolo                  95691
#  2306              5189             Yolo                  95691
#  2307              4770             Yuba                  95901
#  2308              2396             Yuba                  95901
#  2309              5434             Yuba                  95961
#
#       Approximate Location  \
#  0                 Oakland
#  1                 Oakland
#  2                 Oakland
#  3                 Oakland
#  4                 Oakland
#  ...                   ...
#  2305      West Sacramento
#  2306      West Sacramento
#  2307           Marysville
#  2308                Linda
#  2309           Olivehurst
#
#                                                   DAC category
#  0                                 CalEnviroScreen 4.0 Top 25%
#  1                                 CalEnviroScreen 4.0 Top 25%
#  2                                 CalEnviroScreen 4.0 Top 25%
#  3                                 CalEnviroScreen 4.0 Top 25%
#  4                                 CalEnviroScreen 4.0 Top 25%
#  ...                                                       ...
#  2305                              CalEnviroScreen 4.0 Top 25%
#  2306                              CalEnviroScreen 4.0 Top 25%
#  2307                              CalEnviroScreen 4.0 Top 25%
#  2308  2017 Disadvantaged Community (CalEnviroScreen 3.0 only)
#  2309                              CalEnviroScreen 4.0 Top 25%
#
#  [2310 rows x 11 columns],
#  'SB535 tribal area list (2022)':      GeoID                              Name Component
#  0    0020R  Agua Caliente Indian Reservation         R
#  1    0020T  Agua Caliente Indian Reservation         T
#  2    0095R          Alturas Indian Rancheria         R
#  3    0120R                  Auburn Rancheria         R
#  4    0120T                  Auburn Rancheria         T
#  ..     ...                               ...       ...
#  143  4500T                Viejas Reservation         T
#  144  4560T         Washoe Ranches Trust Land         T
#  145  4665R               Woodfords Community         R
#  146  4680R                XL Ranch Rancheria         R
#  147  4760R                 Yurok Reservation         R
#
#  [148 rows x 3 columns],
#  'SB535 tract all data (2022)':       Census Tract  Total Population California County    ZIP  \
#  0       6001400900              2471          Alameda   94608
#  1       6001401000              6133          Alameda   94608
#  2       6001401300              3921          Alameda   94609
#  3       6001401400              4732          Alameda   94608
#  4       6001401500              2839          Alameda   94608
#  ...            ...               ...               ...    ...
#  2305    6113010203              5355             Yolo   95691
#  2306    6113010204              5189             Yolo   95691
#  2307    6115040100              4770             Yuba   95901
#  2308    6115040302              2396             Yuba   95901
#  2309    6115040400              5434             Yuba   95961
#
#       Approximate Location   Longitude   Latitude  CES 4.0 Score  \
#  0                 Oakland -122.280244  37.839467      40.706036
#  1                 Oakland -122.271963  37.831217      43.736745
#  2                 Oakland -122.266713  37.818100      43.677589
#  3                 Oakland -122.273376  37.820739      45.084138
#  4                 Oakland -122.280636  37.822923      44.528208
#  ...                   ...         ...        ...            ...
#  2305      West Sacramento -121.563721  38.563765      59.833979
#  2306      West Sacramento -121.532462  38.577783      45.326498
#  2307           Marysville -121.594246  39.151526      51.760832
#  2308                Linda -121.570911  39.127708      39.382454
#  2309           Olivehurst -121.582617  39.099915      49.196056
#
#         CES 4.0 Percentile  CES 4.0 Percentile Range  ...  \
#  0               76.147252                    75-80%  ...
#  1               80.408472                    80-85%  ...
#  2               80.345436                    80-85%  ...
#  3               82.123046                    80-85%  ...
#  4               81.429652                    80-85%  ...
#  ...                   ...                       ...  ...
#  2305            95.600101  95-100% (highest scores)  ...
#  2306            82.312153                    80-85%  ...
#  2307            89.750378                    85-90%  ...
#  2308            73.903177                    70-75%  ...
#  2309            87.014624                    85-90%  ...
#
#       Linguistic Isolation Pctl  Poverty  Poverty Pctl  Unemployment  \
#  0                    63.039654     28.2     50.854271           5.5
#  1                    53.863852     27.0     48.580402           5.0
#  2                    62.241169     42.9     73.316583           5.8
#  3                    38.137772     54.2     86.218593           6.5
#  4                    43.294086     35.6     62.587940           6.8
#  ...                        ...      ...           ...           ...
#  2305                 64.406550     65.9     95.502513          13.3
#  2306                 72.513195     51.2     83.241206          11.1
#  2307                 11.273515     52.0     84.208543           7.3
#  2308                 53.863852     77.5     99.095477          12.7
#  2309                 71.159832     67.4     96.231156          10.9
#
#        Unemployment Pctl  Housing Burden  Housing Burden Pctl  Pop. Char.   \
#  0             51.262363            23.3            75.107731    66.317052
#  1             44.351900            28.5            87.883397    63.098899
#  2             55.023425            18.6            56.856781    67.060721
#  3             62.402395            34.9            96.032953    64.096005
#  4             65.629880            25.9            82.408112    65.991538
#  ...                 ...             ...                  ...          ...
#  2305          94.833420            23.7            76.349810    69.562620
#  2306          89.927121            24.2            77.820025    68.420473
#  2307          69.976575            21.6            69.150824    63.864399
#  2308          93.714211            16.7            47.617237    68.496114
#  2309          89.458615            20.9            66.514575    79.312196
#
#        Pop. Char. Score  Pop. Char. Pctl
#  0             6.879234        74.848714
#  1             6.545407        70.272315
#  2             6.956376        76.059002
#  3             6.648839        71.583459
#  4             6.845467        74.394856
#  ...                ...              ...
#  2305          7.215905        79.538578
#  2306          7.097427        77.975290
#  2307          6.624814        71.293495
#  2308          7.105273        78.088754
#  2309          8.227253        91.868381
#
#  [2310 rows x 59 columns]}

# %%
# collect sb535 sheet names
sb535_sheetnames = list(sb535.keys())

# read in sheets as df
sb535_0 = sb535[sb535_sheetnames[0]]

sb535_1 = sb535[sb535_sheetnames[1]]

sb535_2 = sb535[sb535_sheetnames[2]]

sb535_3 = sb535[sb535_sheetnames[3]]

# combine into df
sb535_df = to_snake_case(pd.concat([sb535_1, sb535_2, sb535_3], ignore_index=True))


# check df
sb535_df.head()
# Out:
#    census_tract  calenviroscreen_4.0_score  calenviroscreen_4.0_percentile  \
# 0  6.001401e+09                  40.706036                       76.147252
# 1  6.001401e+09                  43.736745                       80.408472
# 2  6.001401e+09                  43.677589                       80.345436
# 3  6.001401e+09                  45.084138                       82.123046
# 4  6.001402e+09                  44.528208                       81.429652
#
#   calenviroscreen_4.0__percentile_range  pollution_burden_percentile  \
# 0                                75-80%                    66.409459
# 1                                80-85%                    81.829496
# 2                                80-85%                    73.976353
# 3                                80-85%                    83.385190
# 4                                80-85%                    78.780336
#
#    population_characteristics_percentile  total_population california_county  \
# 0                              74.848714            2471.0          Alameda
# 1                              70.272315            6133.0          Alameda
# 2                              76.059002            3921.0          Alameda
# 3                              71.583459            4732.0          Alameda
# 4                              74.394856            2839.0          Alameda
#
#    approximate_zip_code approximate_location  ... linguistic_isolation_pctl  \
# 0               94608.0              Oakland  ...                       NaN
# 1               94608.0              Oakland  ...                       NaN
# 2               94609.0              Oakland  ...                       NaN
# 3               94608.0              Oakland  ...                       NaN
# 4               94608.0              Oakland  ...                       NaN
#
#   poverty poverty_pctl unemployment  unemployment_pctl  housing_burden  \
# 0     NaN          NaN          NaN                NaN             NaN
# 1     NaN          NaN          NaN                NaN             NaN
# 2     NaN          NaN          NaN                NaN             NaN
# 3     NaN          NaN          NaN                NaN             NaN
# 4     NaN          NaN          NaN                NaN             NaN
#
#    housing_burden_pctl  pop._char.  pop._char._score pop._char._pctl
# 0                  NaN         NaN               NaN             NaN
# 1                  NaN         NaN               NaN             NaN
# 2                  NaN         NaN               NaN             NaN
# 3                  NaN         NaN               NaN             NaN
# 4                  NaN         NaN               NaN             NaN
#
# [5 rows x 68 columns]

# %%
# set display options to see the full content
pd.set_option('display.max_colwidth', None)

# let's see what our metadata is telling us
print(sb535_0.iloc[:5, 0])
# Out:
# 0                                                   The following tabs in this Excel file contain the list of disadvantaged communities (DACs) designated by CalEPA.
# 1                 The second tab "SB 535 tract list" contains the list of census tracts identified as DACs by use of the CalEnivroScreen tool. (Data dictonary below)
# 2    The third tab "SB535 tribal area list" contains the list of tribal areas in California that are identified as DACs. (Data dictionary at the bottom of this page)
# 3                 A Tribe may establish that a particular area of land is under its control, for purposes of this designation, by requesting a consultation with the
# 4                                               CalEPA Deputy Secretary for Environmental Justice, Tribal Affairs and Border Relations at TribalAffairs@calepa.ca.gov
# Name: SB535 Disadvantaged Communities List (2022), dtype: object

# %%
sb535_1.columns
# Out:
# Index(['Census Tract', 'CalEnviroScreen\n4.0 Score',
#        'CalEnviroScreen\n4.0 Percentile',
#        'CalEnviroScreen 4.0 \nPercentile Range',
#        'Pollution Burden\nPercentile',
#        'Population Characteristics\nPercentile', 'Total Population',
#        'California County', 'Approximate Zip Code', 'Approximate Location',
#        'DAC category'],
#       dtype='object')

# %%
sb535_2.columns
# Out:
# Index(['GeoID', 'Name', 'Component'], dtype='object')

# %%
sb535_3.columns
# Out:
# Index(['Census Tract', 'Total Population', 'California County', 'ZIP',
#        'Approximate Location', 'Longitude', 'Latitude', 'CES 4.0 Score',
#        ' CES 4.0 Percentile', 'CES 4.0 Percentile Range', 'DAC category',
#        'Ozone', 'Ozone Pctl', 'PM2.5', 'PM2.5 Pctl', 'Diesel PM',
#        'Diesel PM Pctl', 'Drinking Water', 'Drinking Water Pctl', 'Lead',
#        'Lead Pctl', 'Pesticides', 'Pesticides Pctl', 'Tox. Release',
#        'Tox. Release Pctl', 'Traffic', 'Traffic Pctl', 'Cleanup Sites',
#        'Cleanup Sites Pctl', 'Groundwater Threats', 'Groundwater Threats Pctl',
#        'Haz. Waste', 'Haz. Waste Pctl', 'Imp. Water Bodies',
#        'Imp. Water Bodies Pctl', 'Solid Waste', 'Solid Waste Pctl',
#        'Pollution Burden', 'Pollution Burden Score', 'Pollution Burden Pctl',
#        'Asthma', 'Asthma Pctl', 'Low Birth Weight', 'Low Birth Weight Pctl',
#        'Cardiovascular Disease', 'Cardiovascular Disease Pctl', 'Education',
#        'Education Pctl', 'Linguistic Isolation', 'Linguistic Isolation Pctl',
#        'Poverty', 'Poverty Pctl', 'Unemployment', 'Unemployment Pctl',
#        'Housing Burden', 'Housing Burden Pctl', 'Pop. Char. ',
#        'Pop. Char. Score', 'Pop. Char. Pctl'],
#       dtype='object')

# %%
sb535_df.columns
# Out:
# Index(['census_tract', 'calenviroscreen_4.0_score',
#        'calenviroscreen_4.0_percentile',
#        'calenviroscreen_4.0__percentile_range', 'pollution_burden_percentile',
#        'population_characteristics_percentile', 'total_population',
#        'california_county', 'approximate_zip_code', 'approximate_location',
#        'dac_category', 'geoid', 'name', 'component', 'zip', 'longitude',
#        'latitude', 'ces_4.0_score', 'ces_4.0_percentile',
#        'ces_4.0_percentile_range', 'ozone', 'ozone_pctl', 'pm2.5',
#        'pm2.5_pctl', 'diesel_pm', 'diesel_pm_pctl', 'drinking_water',
#        'drinking_water_pctl', 'lead', 'lead_pctl', 'pesticides',
#        'pesticides_pctl', 'tox._release', 'tox._release_pctl', 'traffic',
#        'traffic_pctl', 'cleanup_sites', 'cleanup_sites_pctl',
#        'groundwater_threats', 'groundwater_threats_pctl', 'haz._waste',
#        'haz._waste_pctl', 'imp._water_bodies', 'imp._water_bodies_pctl',
#        'solid_waste', 'solid_waste_pctl', 'pollution_burden',
#        'pollution_burden_score', 'pollution_burden_pctl', 'asthma',
#        'asthma_pctl', 'low_birth_weight', 'low_birth_weight_pctl',
#        'cardiovascular_disease', 'cardiovascular_disease_pctl', 'education',
#        'education_pctl', 'linguistic_isolation', 'linguistic_isolation_pctl',
#        'poverty', 'poverty_pctl', 'unemployment', 'unemployment_pctl',
#        'housing_burden', 'housing_burden_pctl', 'pop._char.',
#        'pop._char._score', 'pop._char._pctl'],
#       dtype='object')

# %%
sb535_geo = gpd.GeoDataFrame(sb535_df,
                             geometry = gpd.points_from_xy(sb535_df.longitude, sb535_df.latitude),
                             crs = 'EPSG:4269')

sb535_geo.head(3)

# print information about the 
print('is geographic?: ', sb535_geo.crs.is_geographic)
print('is projected?: ', sb535_geo.crs.is_projected)
print('datum: ', sb535_geo.crs.datum)
print('ellipsoid: ', sb535_geo.crs.ellipsoid)

sb535_geo.crs
# Out:
# is geographic?:  True
# is projected?:  False
# datum:  North American Datum 1983
# ellipsoid:  GRS 1980
# <Geographic 2D CRS: EPSG:4269>
# Name: NAD83
# Axis Info [ellipsoidal]:
# - Lat[north]: Geodetic latitude (degree)
# - Lon[east]: Geodetic longitude (degree)
# Area of Use:
# - name: North America - onshore and offshore: Canada - Alberta; British Columbia; Manitoba; New Brunswick; Newfoundland and Labrador; Northwest Territories; Nova Scotia; Nunavut; Ontario; Prince Edward Island; Quebec; Saskatchewan; Yukon. Puerto Rico. United States (USA) - Alabama; Alaska; Arizona; Arkansas; California; Colorado; Connecticut; Delaware; Florida; Georgia; Hawaii; Idaho; Illinois; Indiana; Iowa; Kansas; Kentucky; Louisiana; Maine; Maryland; Massachusetts; Michigan; Minnesota; Mississippi; Missouri; Montana; Nebraska; Nevada; New Hampshire; New Jersey; New Mexico; New York; North Carolina; North Dakota; Ohio; Oklahoma; Oregon; Pennsylvania; Rhode Island; South Carolina; South Dakota; Tennessee; Texas; Utah; Vermont; Virginia; Washington; West Virginia; Wisconsin; Wyoming. US Virgin Islands. British Virgin Islands.
# - bounds: (167.65, 14.92, -40.73, 86.45)
# Datum: North American Datum 1983
# - Ellipsoid: GRS 1980
# - Prime Meridian: Greenwich

# %%
# confirm we have the right info (aka CA)
sb535_geo.plot()
# Out:
# <Axes: >

# %% [markdown]
# #####  CalEnviroScreen Data
# `ciscore` is the CalEnviroScore I believe, need to check meta

# %%
calenviro = gpd.read_file('../data/CalEnviroScreen/CES4 Final Shapefile.shp')

calenviro = to_snake_case(calenviro)

calenviro.head(1)
# Out:
#           tract    zip         county    approxloc  totpop19    ciscore  \
# 0  6.083002e+09  93454  Santa Barbara  Santa Maria      4495  36.019653
#
#     ciscorep    ozone     ozonep     pm2_5  ...  elderly65  hispanic    white  \
# 0  69.162885  0.03419  10.566273  7.567724  ...    12.5028    68.921  20.8899
#
#    africanam  nativeam  othermult   shape_leng    shape_area    aapi  \
# 0     0.4004     0.267     1.3126  6999.357689  2.847611e+06  8.2091
#
#                                                                                                                                                                                                                              geometry
# 0  POLYGON ((-39795.070 -341919.191, -38126.384 -341949.463, -38140.258 -343585.801, -38973.138 -343565.215, -39101.124 -343580.515, -39297.113 -343651.682, -39656.690 -343854.660, -39803.632 -343880.520, -39795.070 -341919.191))
#
# [1 rows x 67 columns]

# %%
# crs config
calenviro = calenviro.to_crs(sb535_geo.crs)

# dtypes
calenviro.dtypes
# Out:
# tract          float64
# zip              int64
# county          object
# approxloc       object
# totpop19         int64
#                 ...
# othermult      float64
# shape_leng     float64
# shape_area     float64
# aapi           float64
# geometry      geometry
# Length: 67, dtype: object

# %%
calenviro.plot()
# Out:
# <Axes: >

# %% [markdown]
# ### SD Climate Equity Index (SD_CEI)

# %%
sd_cei = gpd.read_file('../data/sd_climate_equity_index/City_of_San_Diego_CEI_2021_Revision.shp')

sd_cei = to_snake_case(sd_cei)

#sd_cei.head(3)

# %%
# match crs
sd_cei = sd_cei.to_crs(sb535_geo.crs)

# dtypes
sd_cei.dtypes
# Out:
# tract          float64
# cei_score_       int64
# cei_class_      object
# cei_score1       int64
# cei_class1      object
# flood_risk     float64
# fire_risk      float64
# tree_cover     float64
# urban_heat     float64
# proximity_     float64
# pesticide_     float64
# drinking_w     float64
# groundwate     float64
# impaired_w     float64
# air_qualit     float64
# air_qual_1     float64
# air_qual_2     float64
# toxic_rele     float64
# cleanup_si     float64
# hazardous_     float64
# solid_wast     float64
# unemployme     float64
# educationa     float64
# linguistic     float64
# digital_ac     float64
# median_inc     float64
# poverty_ra     float64
# income_cha     float64
# energy_cos     float64
# solar_phot     float64
# housing_co     float64
# overcrowde     float64
# pedestrian     float64
# commute_bu     float64
# transporta     float64
# disability     float64
# street_con     float64
# bikeabilit     float64
# access_to_     float64
# traffic_de     float64
# electric_v     float64
# asthma_rat     float64
# cancer_fat     float64
# healthy_fo     float64
# low_infant     float64
# cardiovasc     float64
# geometry      geometry
# dtype: object

# %%
sd_cei.plot()
# Out:
# <Axes: >

# %% [markdown]
# ### EJScreen Tool Data
#
# `id` is the tract_id

# %%
# read in data & clean colnames 
ejscreen = to_snake_case(pd.read_csv('../data/EJSCREEN_2023_Tracts_StatePct_with_AS_CNMI_GU_VI.csv'))

# isolate CA
ejscreen = ejscreen[ejscreen.state_name == 'California']

# %%
ejscreen
# Out:
#         oid_          id  state_name st_abbrev cnty_name  region  acstotpop  \
# 4202    4203  6001400100  California        CA   Alameda       9     3324.0
# 4203    4204  6001400200  California        CA   Alameda       9     2038.0
# 4204    4205  6001400300  California        CA   Alameda       9     5449.0
# 4205    4206  6001400400  California        CA   Alameda       9     4384.0
# 4206    4207  6001400500  California        CA   Alameda       9     4048.0
# ...      ...         ...         ...       ...       ...     ...        ...
# 13326  13327  6115040902  California        CA      Yuba       9     1730.0
# 13327  13328  6115041001  California        CA      Yuba       9     3910.0
# 13328  13329  6115041002  California        CA      Yuba       9     3408.0
# 13329  13330  6115041101  California        CA      Yuba       9     2620.0
# 13330  13331  6115041102  California        CA      Yuba       9      890.0
#
#        acsipovbas  acseducbas  acstothh  ...  p_d2_pwdis  p_d5_pwdis  \
# 4202       3313.0      2513.0    1337.0  ...        29.0        25.0
# 4203       2038.0      1621.0     868.0  ...        26.0        28.0
# 4204       5410.0      4358.0    2548.0  ...        34.0        29.0
# 4205       4384.0      3333.0    1826.0  ...        32.0        27.0
# 4206       4039.0      3101.0    1673.0  ...        50.0        43.0
# ...           ...         ...       ...  ...         ...         ...
# 13326      1041.0       516.0     357.0  ...        54.0        56.0
# 13327      3901.0      2996.0    1407.0  ...        27.0        41.0
# 13328      3386.0      2567.0    1451.0  ...        22.0        32.0
# 13329      2620.0      1899.0    1128.0  ...        34.0        58.0
# 13330       890.0       789.0     464.0  ...        20.0        40.0
#
#           arealand   areawater  npl_cnt  tsdf_cnt  exceed_count_80  \
# 4202     6945856.0         0.0        0         0                0
# 4203      586560.0         0.0        0         0                0
# 4204     1110840.0         0.0        0         0                0
# 4205      716138.0         0.0        0         0                0
# 4206      591424.0         0.0        0         1                1
# ...            ...         ...      ...       ...              ...
# 13326   93603063.0    240059.0        0         1                0
# 13327  275920634.0   1720985.0        0         0                0
# 13328  192476772.0   5206412.0        0         0                0
# 13329  464905359.0  16529900.0        0         0                0
# 13330   94410923.0    550493.0        0         0                0
#
#        exceed_count_80_sup  shape_length  shape_area
# 4202                   0.0      0.143536    0.000711
# 4203                   0.0      0.041978    0.000060
# 4204                   0.0      0.055377    0.000114
# 4205                   0.0      0.037278    0.000073
# 4206                   0.0      0.033224    0.000061
# ...                    ...           ...         ...
# 13326                  0.0      0.513671    0.009775
# 13327                  0.0      0.892114    0.028971
# 13328                  0.0      0.897197    0.020640
# 13329                  0.0      1.580023    0.050389
# 13330                  0.0      0.665122    0.009925
#
# [9129 rows x 126 columns]

# %%
ejscreen.columns.tolist()

ejscreen.dtypes
# Out:
# oid_                     int64
# id                       int64
# state_name              object
# st_abbrev               object
# cnty_name               object
#                         ...
# tsdf_cnt                 int64
# exceed_count_80          int64
# exceed_count_80_sup    float64
# shape_length           float64
# shape_area             float64
# Length: 126, dtype: object

# %%
ejscreen_geo.plot()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /Users/sofiaingersoll/2035/iee_grid_modeling_project/Script/identifying_ctracts_oversampling.ipynb Cell 29 line 1
# ----> <a href='vscode-notebook-cell:/Users/sofiaingersoll/2035/iee_grid_modeling_project/Script/identifying_ctracts_oversampling.ipynb#X42sZmlsZQ%3D%3D?line=0'>1</a> ejscreen_geo.plot()
#
# NameError: name 'ejscreen_geo' is not defined

# %% [markdown]
# ### White House Map

# %%
wh_map = gpd.read_file('../data/white_house_map/usa/usa.shp',
                       crs = sb535_geo.crs)

# %%
wh_map = to_snake_case(wh_map)

wh_map.columns
# Out:
# Index(['geoid10', 'sf', 'cf', 'df_pfs', 'af_pfs', 'hdf_pfs', 'dsf_pfs',
#        'ebf_pfs', 'ealr_pfs', 'eblr_pfs',
#        ...
#        'age_10', 'age_middle', 'age_old', 'ta_cou_116', 'ta_count_c',
#        'ta_perc', 'ta_perc_fe', 'ui_exp', 'thrhld', 'geometry'],
#       dtype='object', length=124)

# %%
wh_ca = wh_map[wh_map.sf == 'California']

#wh_ca.head(1)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# /var/folders/n4/2w_c819n7nv4fr_mvn5wpsnc0000gn/T/ipykernel_38098/298586028.py in ?()
# ----> 1 wh_ca = wh_map[wh_map.sf == 'California']
#       2
#       3 #wh_ca.head(1)
#
# ~/anaconda3/envs/eds-env/lib/python3.11/site-packages/pandas/core/generic.py in ?(self, name)
#    6289             and name not in self._accessors
#    6290             and self._info_axis._can_hold_identifiers_and_holds_name(name)
#    6291         ):
#    6292             return self[name]
# -> 6293         return object.__getattribute__(self, name)
#
# AttributeError: 'GeoDataFrame' object has no attribute 'sf'

# %%
wh_ca.plot()
# Out:
# <Axes: >

# %% [markdown]
# ### Climate and Vulnerability Factors
#
# Air Conditioning lacks geolocations, so there's a strong chance we will have to rely on `county_fips` or `geotypevalue` matching from merging the datasets with one that contains coordinates.
#
# Plan is to likely combine all metric data into a df to then combine with a single df with geolocations and `county_fips`, then plot to check accuracy

# %%
air_conditioning = pd.read_excel('../data/Climate_Vulnerability_Metric_Indicators/BRACE_AirConditioning_797_CO_RE_CA.xlsx', sheet_name=None)
 
# collect Clim. Vuln. Factor air conditioning sheet names
ac_sheetnames = list(air_conditioning.keys())

ac_sheetnames
# Out:
# ['ReadMe',
#  'Data',
#  'DataDictionary',
#  'DataFilteringInstructions',
#  'AIR_Regions']

# %%
# read in sheets as df
ac_README = air_conditioning[ac_sheetnames[0]]

ac_data = air_conditioning[ac_sheetnames[1]]

ac_dict = air_conditioning[ac_sheetnames[2]]

# %%
ac_README
# Out:
#                                   Term  \
# 0                              Project
# 1                       Indicator Name
# 2                 Indicator Short Name
# 3                          Data Source
# 4                              Creator
# 5                              Version
# 6                        Documentation
# 7                        Contents.Data
# 8              Contents.DataDictionary
# 9   Contents.DataFilteringInstructions
# 10                      Contents.Other
#
#                                                                                                       Title  \
# 0                                 California Building Resilience Against Climate Effects (CalBRACE) Project
# 1                                                                                          Air Conditioning
# 2                                                            Percent of households without air conditioning
# 3   2009 Residential Appliance Saturation Study (RASS). (https://websafe.kemainc.com/RASS2009/Default.aspx)
# 4                                                                                     CalBRACE @cdph.ca.gov
# 5                                                                                       2016-12-13 00:00:00
# 6                                                                              < insert link to narrative >
# 7                                                                                                      Data
# 8                                                                                            DataDictionary
# 9                                                                                 DataFilteringInstructions
# 10                                                                                              AIR_Regions
#
#                                                                                                                                          Description
# 0                                                                                                                                                NaN
# 1                                                                                                                                                NaN
# 2                                                                                                                                                NaN
# 3                                                                                                                                                NaN
# 4                                                                                                                                                NaN
# 5                                                                                                                                                NaN
# 6                                                                                                                                                NaN
# 7   Data on the percent of households with air conditioning for California at multiple geographical levels: county (CO), region (RE), and state (CA)
# 8                                                                                                Description of all of the variables in the Data tab
# 9                                                                              Instructions on how to apply filters to navigate the data in the file
# 10                                                                   Description of the counties included in each of the  Adaptation Impact Regions.

# %%
ac_data.columns
# Out:
# Index(['county_name', 'ind_id', 'ind_definition', 'reportyear',
#        'race_eth_code', 'race_eth_name', 'geotype', 'geotypevalue', 'geoname',
#        'county_fips', 'strata_one_code', 'strata_one_name', 'strata_two_code',
#        'strata_two_name', 'numerator', 'denominator', 'estimate', 'LL_95CI',
#        'UL_95CI', 'SE', 'RSE', 'CA_decile', 'CA_RR', 'version', 'region_code',
#        'region_name'],
#       dtype='object')

# %%
ac_dict
# Out:
#                      Name   \
# 0                   ind_id
# 1           ind_definition
# 2               reportyear
# 3            race_eth_code
# 4            race_eth_name
# 5                  geotype
# 6             geotypevalue
# 7                  geoname
# 8              county_name
# 9              county_fips
# 10             region_name
# 11             region_code
# 12        strata_name_code
# 13             strata_name
# 14  strata_level_name_code
# 15       strata_level_name
# 16               numerator
# 17             denominator
# 18                 percent
# 19         LL_95CI_percent
# 20         UL_95CI_percent
# 21              percent_se
# 22             percent_rse
# 23               CA_decile
# 24                   CA_RR
# 25                 version
#
#                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                       Definition  \
# 0                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                   Indicator ID
# 1                                                                                                                                                                                                                                                                                                                                                                                                                                                                                      Definition of indicator in plain language
# 2                                                                                                                                                                                                                                                                                                                                                                                                                                                                                           Year that the indicator was reported
# 3                                                                                                                                                                                                                                                                                                                                                                                                                                                                                        numeric code for a race/ethnicity group
# 4                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                      Name of race/ethnic group
# 5                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                        Type of geographic unit
# 6                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                       Value of geographic unit
# 7                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                        Name of geographic unit
# 8                                                                                                                                                                                                                                                                                                                                                                                                                                                                                              Name of county that geotype is in
# 9                                                                                                                                                                                                                                                                                                                                                                                                                                                                                         FIPS code of county that geotype is in
# 10                                                                                                                                                                                                                                                                                                                                                                                                                                                                  Adaptation Impact Region (AIR) name; see AIR_County list tab
# 11                                                                                                                                                                                                                                                                                                                                                                                                                                                                  Adaptation Impact Region (AIR) code; see AIR_County list tab
# 12                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                          code for strata name
# 13                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                name of strata
# 14                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                         code for strata level
# 15                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                          strata category name
# 16                                                                                                                                                                                                                                                                                                                                                                                                                                                        Estimated number of occupied households with air conditionig ownership
# 17                                                                                                                                                                                                                                                                                                                                                                                                                                                                                           Total number of occupied households
# 18                                                                                                                                                                                                                                                                                                                                                                                                                                                                                   Percent of households with air conditioning
# 19                                                                                                                                                                   Lower limit of 95% confidence interval around the estimate: The 95% confidence limits depict the range within which the percentage would probably occur in 95 of 100 sets of data (if data similar to the present set were independently acquired on 100 separate occasions). In five of those 100 data sets, the percentage would fall outside the limits.
# 20                                                                                                                                                                                                                                                                                                                                                                                                                                                                                     Upper limit of 95% confidence interval.
# 21                                                                                                                                                                                                                                                                                                                        Standard error of the estimate: measure of the precision of the sample mean.  The standard error falls as the sample size increases. (Reference: http://www.ncbi.nlm.nih.gov/pmc/articles/PMC1255808/)
# 22  Relative standard error (se/estimate * 100) expressed as a percent: provides the rational basis for determining which estimates may be considered “unreliable.” Conforming to National Center for Health Statistics (NCHS) standards, estimates that are calculated from fewer than 20 data elements, the equivalent of an RSE of 23 percent or more, are considered unreliable (http://www.cdph.ca.gov/programs/ohir/Documents/OHIRProfiles2014.pdf).  For this project we consider estimates with RSE ≥ 30% as unreliable.
# 23              Statewide decile ranking: 'CA_decile' groups places into 10 groups (or deciles) according to the distribution of values of the estimate. Highest estimate values are included in the first decile.  Equal values or 'ties' are assigned the mean decile rank. For example, in a database of 100 records where 70 records equal 0, 0 values span from the 1st to 7th deciles (70% of all data records). As a result, all 0 values will be assigned to the 4th decile: the mean between the 1st and 7th deciles.
# 24                                                                                                                                                                                                                                                                                                        California Ratio: ratio estimate/state estimate; indicates how many times the local estimate is higher or lower than the state estimate. Values higher than 1 indicate local estimate are higher than state estimates.
# 25                                                                                                                                                                                                                                                                                                                                                                                                                                                                              Date/time stamp of version of data file creation
#
#    Type  \
# 0     N
# 1     T
# 2     T
# 3     T
# 4     T
# 5     T
# 6     N
# 7     T
# 8     T
# 9     T
# 10    T
# 11    T
# 12    N
# 13    T
# 14    N
# 15    T
# 16    N
# 17    N
# 18    N
# 19    N
# 20    N
# 21    N
# 22    N
# 23    N
# 24    N
# 25   DT
#
#                                                                                                                                                                                                                           Coding
# 0                                                                                                                                                                                                                             26
# 1                                                                                                                                                                                                                      Free text
# 2                                                                                                                                                                                                                           2009
# 3                                                                                           1 = American Indian; 2 = Asian or Pacific; 3 = Black or African American; 4 = Hispanic or Latino; 6 = White or Caucasian; 8 = Other;
# 4                                                                                                                   American Indian; Asian or Pacific; Black or African American; Hispanic or Latino; White or Caucasian; Other;
# 5                                                                                                                                                                                                 CO County; RE Region; CA State
# 6                                                                                                                                                                                                             FIPS ID; region id
# 7                                                                                                                                                                                                     county, region name, state
# 8                                                                                                                                                                                                                            NaN
# 9                                                                                                                                                                 2-digit census state code (06) plus 3-digit census county code
# 10                                                                                                                                                                                                                           NaN
# 11                          01 = North; 02 = North Coast; 03 = Bay Area; 04 = Northern Central Valley; 06 = Southern Central Valley; 07 = Central Coast; 08 = North Sierra; 09 = Southeast Sierra; 10 = South Coast; 11 = Desert
# 12                                                                                                                                                                            1 = Race_Ethnicity; 2 = Income Category; 9 = Total
# 13                                                                                                                                                                                        Race_Ethnicity; Income Category; Total
# 14  1 = American Indian; 2 = Asian or Pacific; 3 = Black or African American; 4 = Hispanic or Latino; 5 = White or Caucasian; 6 = Other; 1 = $0-$30,000; 2 = $30,000 - $75,000; 3 = $75,000 - $150,000; 4 = >$150,000; 9 = Total
# 15                                              American Indian; Asian or Pacific; Black or African American; Hispanic or Latino; White or Caucasian; Other; $0-$30,000; $30,000 - $75,000; $75,000 - $150,000; >$150,000; Total
# 16                                                                                                                                                                                                                           NaN
# 17                                                                                                                                                                                                                           NaN
# 18                                                                                                                                                                                                                           NaN
# 19                                                                                                                                                                                                                           NaN
# 20                                                                                                                                                                                                                           NaN
# 21                                                                                                                                                                                                                           NaN
# 22                                                                                                                                                                                                                           NaN
# 23                                                                                                                                                                                                                           NaN
# 24                                                                                                                                                                                                                           NaN
# 25                                                                                                                                                                                                           mm/DD/CCYY hh:mm:ss

# %%
ac_data.county_fips
# Out:
# 0        NaN
# 1        NaN
# 2        NaN
# 3        NaN
# 4        NaN
#        ...
# 74    6107.0
# 75    6109.0
# 76    6111.0
# 77    6113.0
# 78    6115.0
# Name: county_fips, Length: 79, dtype: float64

# %%
folder = '../data/Climate_Vulnerability_Metric_Indicators/'
combo_metric_df = pd.DataFrame()

for file_name in os.listdir(folder):
    if file_name.endswith('.xlsx') or file_name.endswith('.XLSX'):
        file_path = os.path.join(folder, file_name)
        
        # Read Excel file with all sheets into a dictionary
        temp_df = pd.read_excel(file_path, sheet_name=None)
        
        # Assuming you want to extract the second sheet from each file
        for sheet_name, df in temp_df.items():
            if sheet_name == 'Data':  # Adjust sheet name as needed
                # Concatenate to the combined DataFrame
                combo_metric_df = pd.concat([combo_metric_df, df], ignore_index=True)

# Print the concatenated DataFrame if it's not empty
if not combo_metric_df.empty:
    print(combo_metric_df)
else:
    print("No data found or failed to concatenate properly.")
# Out:
# /Users/sofiaingersoll/anaconda3/envs/eds-env/lib/python3.11/site-packages/openpyxl/worksheet/header_footer.py:48: UserWarning: Cannot parse header or footer so it will be ignored
#   warn("""Cannot parse header or footer so it will be ignored""")
# /Users/sofiaingersoll/anaconda3/envs/eds-env/lib/python3.11/site-packages/openpyxl/worksheet/header_footer.py:48: UserWarning: Cannot parse header or footer so it will be ignored
#   warn("""Cannot parse header or footer so it will be ignored""")
#          ind_id                                     ind_definition reportyear  \
# 0         355.0  Percent of population age 25 and up with a fou...       2000
# 1         355.0  Percent of population age 25 and up with a fou...       2000
# 2         355.0  Percent of population age 25 and up with a fou...       2000
# 3         355.0  Percent of population age 25 and up with a fou...       2000
# 4         355.0  Percent of population age 25 and up with a fou...       2000
# ...         ...                                                ...        ...
# 1442521   187.0     Percent of population without health insurance       2015
# 1442522   187.0     Percent of population without health insurance       2015
# 1442523   187.0     Percent of population without health insurance       2015
# 1442524   187.0     Percent of population without health insurance       2015
# 1442525   187.0     Percent of population without health insurance       2015
#
#          race_eth_code race_eth_name geotype  geotypevalue  \
# 0                  3.0     AfricanAm      CA           6.0
# 1                  1.0          AIAN      CA           6.0
# 2                  2.0         Asian      CA           6.0
# 3                  4.0        Latino      CA           6.0
# 4                  7.0      Multiple      CA           6.0
# ...                ...           ...     ...           ...
# 1442521            9.0         Total      PL       67000.0
# 1442522            2.0         Asian      PL       67000.0
# 1442523            2.0         Asian      PL       68000.0
# 1442524            6.0         White      PL       68000.0
# 1442525            6.0         White      PL       67000.0
#
#                     geoname    county_name  county_fips  ... COUNTY_FIPS  \
# 0                California            NaN          NaN  ...         NaN
# 1                California            NaN          NaN  ...         NaN
# 2                California            NaN          NaN  ...         NaN
# 3                California            NaN          NaN  ...         NaN
# 4                California            NaN          NaN  ...         NaN
# ...                     ...            ...          ...  ...         ...
# 1442521  San Francisco city  San Francisco          NaN  ...      6075.0
# 1442522  San Francisco city  San Francisco          NaN  ...      6075.0
# 1442523       San Jose city    Santa Clara          NaN  ...      6085.0
# 1442524       San Jose city    Santa Clara          NaN  ...      6085.0
# 1442525  San Francisco city  San Francisco          NaN  ...      6075.0
#
#          Region_name  Region_code   se  County_FIPS ll_95ci  ul_95ci  rse  \
# 0                NaN          NaN  NaN          NaN     NaN      NaN  NaN
# 1                NaN          NaN  NaN          NaN     NaN      NaN  NaN
# 2                NaN          NaN  NaN          NaN     NaN      NaN  NaN
# 3                NaN          NaN  NaN          NaN     NaN      NaN  NaN
# 4                NaN          NaN  NaN          NaN     NaN      NaN  NaN
# ...              ...          ...  ...          ...     ...      ...  ...
# 1442521     Bay Area          3.0  NaN          NaN     NaN      NaN  NaN
# 1442522     Bay Area          3.0  NaN          NaN     NaN      NaN  NaN
# 1442523     Bay Area          3.0  NaN          NaN     NaN      NaN  NaN
# 1442524     Bay Area          3.0  NaN          NaN     NaN      NaN  NaN
# 1442525     Bay Area          3.0  NaN          NaN     NaN      NaN  NaN
#
#          ca_decile  ca_rr
# 0              NaN    NaN
# 1              NaN    NaN
# 2              NaN    NaN
# 3              NaN    NaN
# 4              NaN    NaN
# ...            ...    ...
# 1442521        NaN    NaN
# 1442522        NaN    NaN
# 1442523        NaN    NaN
# 1442524        NaN    NaN
# 1442525        NaN    NaN
#
# [1442526 rows x 38 columns]

# %%
# let's make sure we loaded the right amount of xlsx
len(combo_metric_df.ind_definition.unique())
# Out:
# 21

# %%
# and double check the indicators are included as expected
# bc we got more than expected it should be 19
# the duplicates we're seeing are caused by spaces in the text
# Percent of households with no one aged >14 years speaking English',
# Percent of population employed and aged >16 working outdoors'
combo_metric_df.ind_definition.unique()
# Out:
# array(['Percent of population age 25 and up with a four-year college degree or higher',
#        'Percent of the land area covered by impervious surfaces',
#        'Average Daily Maximum Ozone Concentration',
#        'Percent of households with air conditioning', nan,
#        'Projected number of extreme heat days (per year)',
#        'Percent of households with no vehicle ownership',
#        'Percent of population with a disability',
#        'Percent of population by race and ethnicity',
#        'Population living in sea level rise inundation areas',
#        'Percent without tree canopy coverage',
#        'Annual Mean Ambient Concentration of Fine Particulate Matter (PM2.5)',
#        'Percent of population aged 65 years or older',
#        'Percent of households with no one aged >14 years speaking English',
#        'Percent of households with no one aged > 14 years speaking English',
#        'Percent of population age less than 5 years',
#        'Percent of population currently living in very high wildfire risk areas',
#        'Overall, Concentrated, and Child (under 18 years of age) Poverty Rate',
#        'Percent of population employed and aged >16 working outdoors',
#        'Percent of population employed and aged > 16 working outdoors',
#        'Percent of population without health insurance'], dtype=object)

# %%
combo_metric_df.columns
# Out:
# Index(['ind_id', 'ind_definition', 'reportyear', 'race_eth_code',
#        'race_eth_name', 'geotype', 'geotypevalue', 'geoname', 'county_name',
#        'county_fips', 'region_name', 'region_code', 'strata_one_code',
#        'strata_one_name', 'strata_two_code', 'strata_two_name', 'numerator',
#        'denominator', 'estimate', 'LL_95CI', 'UL_95CI', 'SE', 'RSE',
#        'CA_decile', 'CA_RR', 'version', 'Geoname', 'County_Name',
#        'COUNTY_FIPS', 'se', 'Region_name', 'Region_code'],
#       dtype='object')

# %%
# load drought metric NETCDF data
# fabulous, it contains geolocation data
# let's merge this with the combo metric data and see how it plots
drought_path = os.path.join(folder, 'pdsi_current_PRISM.nc')

drought = xr.open_dataset(drought_path)
drought_df = drought.to_dataframe()

# okay lat/long are indexes, this is an issue for combining
drought_df = drought_df.reset_index()
drought_df

# mental note to check later: how is day going to influence the join?
# i think should be fine bc of year vs day but there's no way of matching the og planned columns to this df
# need to make a db schema to visualize how i can relate these df properly
# going to just go through the hairy wkflw for now and correct these errors tomorrow
# Out:
#          longitude   latitude        day  data
# 0      -125.020836  24.062500 2024-06-15   NaN
# 1      -125.020836  24.104166 2024-06-15   NaN
# 2      -125.020836  24.145834 2024-06-15   NaN
# 3      -125.020836  24.187500 2024-06-15   NaN
# 4      -125.020836  24.229166 2024-06-15   NaN
# ...            ...        ...        ...   ...
# 872500  -66.520836  49.729168 2024-06-15   NaN
# 872501  -66.520836  49.770832 2024-06-15   NaN
# 872502  -66.520836  49.812500 2024-06-15   NaN
# 872503  -66.520836  49.854168 2024-06-15   NaN
# 872504  -66.520836  49.895832 2024-06-15   NaN
#
# [872505 rows x 4 columns]

# %%
drought_geo = gpd.GeoDataFrame(drought,
                               geometry = gpd.points_from_xy(drought['longitude'], drought['latitude']),
                               crs = 'EPSG:4326')

drought_geo.plot()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /Users/sofiaingersoll/2035/iee_grid_modeling_project/identifying_ctracts_oversampling.ipynb Cell 49 line 2
#       <a href='vscode-notebook-cell:/Users/sofiaingersoll/2035/iee_grid_modeling_project/identifying_ctracts_oversampling.ipynb#Y112sZmlsZQ%3D%3D?line=0'>1</a> drought_geo = gpd.GeoDataFrame(drought,
# ----> <a href='vscode-notebook-cell:/Users/sofiaingersoll/2035/iee_grid_modeling_project/identifying_ctracts_oversampling.ipynb#Y112sZmlsZQ%3D%3D?line=1'>2</a>                                geometry = gpd.points_from_xy(drought['longitude'], drought['latitude']),
#       <a href='vscode-notebook-cell:/Users/sofiaingersoll/2035/iee_grid_modeling_project/identifying_ctracts_oversampling.ipynb#Y112sZmlsZQ%3D%3D?line=2'>3</a>                                crs = 'EPSG:4326')
#       <a href='vscode-notebook-cell:/Users/sofiaingersoll/2035/iee_grid_modeling_project/identifying_ctracts_oversampling.ipynb#Y112sZmlsZQ%3D%3D?line=4'>5</a> drought_geo.plot()
#
# File ~/anaconda3/envs/eds-env/lib/python3.11/site-packages/geopandas/array.py:265, in points_from_xy(x, y, z, crs)
#     222 def points_from_xy(x, y, z=None, crs=None):
#     223     """
#     224     Generate GeometryArray of shapely Point geometries from x, y(, z) coordinates.
#     225
#    (...)
#     263     output : GeometryArray
#     264     """
# --> 265     return GeometryArray(vectorized.points_from_xy(x, y, z), crs=crs)
#
# File ~/anaconda3/envs/eds-env/lib/python3.11/site-packages/geopandas/_vectorized.py:264, in points_from_xy(x, y, z)
#     261     z = np.asarray(z, dtype="float64")
#     263 if compat.USE_SHAPELY_20:
# --> 264     return shapely.points(x, y, z)
#     265 elif compat.USE_PYGEOS:
#     266     return pygeos.points(x, y, z)
#
# File ~/anaconda3/envs/eds-env/lib/python3.11/site-packages/shapely/decorators.py:77, in multithreading_enabled.<locals>.wrapped(*args, **kwargs)
#      75     for arr in array_args:
#      76         arr.flags.writeable = False
# ---> 77     return func(*args, **kwargs)
#      78 finally:
#      79     for arr, old_flag in zip(array_args, old_flags):
#
# File ~/anaconda3/envs/eds-env/lib/python3.11/site-packages/shapely/creation.py:72, in points(coords, y, z, indices, out, **kwargs)
#      34 @multithreading_enabled
#      35 def points(coords, y=None, z=None, indices=None, out=None, **kwargs):
#      36     """Create an array of points.
#      37
#      38     Parameters
#    (...)
#      70       Instead provide the coordinates as an array with shape ``(..., 2)`` or ``(..., 3)`` using only the ``coords`` argument.
#      71     """
# ---> 72     coords = _xyz_to_coords(coords, y, z)
#      73     if indices is None:
#      74         return lib.points(coords, out=out, **kwargs)
#
# File ~/anaconda3/envs/eds-env/lib/python3.11/site-packages/shapely/creation.py:28, in _xyz_to_coords(x, y, z)
#      26     return x
#      27 if z is None:
# ---> 28     coords = np.broadcast_arrays(x, y)
#      29 else:
#      30     coords = np.broadcast_arrays(x, y, z)
#
# File <__array_function__ internals>:200, in broadcast_arrays(*args, **kwargs)
#
# File ~/anaconda3/envs/eds-env/lib/python3.11/site-packages/numpy/lib/stride_tricks.py:540, in broadcast_arrays(subok, *args)
#     533 # nditer is not used here to avoid the limit of 32 arrays.
#     534 # Otherwise, something like the following one-liner would suffice:
#     535 # return np.nditer(args, flags=['multi_index', 'zerosize_ok'],
#     536 #                  order='C').itviews
#     538 args = [np.array(_m, copy=False, subok=subok) for _m in args]
# --> 540 shape = _broadcast_shape(*args)
#     542 if all(array.shape == shape for array in args):
#     543     # Common case where nothing needs to be broadcasted.
#     544     return args
#
# File ~/anaconda3/envs/eds-env/lib/python3.11/site-packages/numpy/lib/stride_tricks.py:422, in _broadcast_shape(*args)
#     417 """Returns the shape of the arrays that would result from broadcasting the
#     418 supplied arrays against each other.
#     419 """
#     420 # use the old-iterator because np.nditer does not handle size 0 arrays
#     421 # consistently
# --> 422 b = np.broadcast(*args[:32])
#     423 # unfortunately, it cannot handle 32 or more arguments directly
#     424 for pos in range(32, len(args), 31):
#     425     # ironically, np.broadcast does not properly handle np.broadcast
#     426     # objects (it treats them as scalars)
#     427     # use broadcasting to avoid allocating the full array
#
# ValueError: shape mismatch: objects cannot be broadcast to a single shape.  Mismatch is between arg 0 with shape (1405,) and arg 1 with shape (621,).

# %%
# combine df
combo_metrics_geo = pd.concat([combo_metric_df, drought_df], ignore_index=True)

#combo_metrics_geo = pd.concat([combo_metric_df, drought_df])

combo_metrics_geo
# Out:
#          ind_id                                     ind_definition reportyear  \
# 0         355.0  Percent of population age 25 and up with a fou...       2000
# 1         355.0  Percent of population age 25 and up with a fou...       2000
# 2         355.0  Percent of population age 25 and up with a fou...       2000
# 3         355.0  Percent of population age 25 and up with a fou...       2000
# 4         355.0  Percent of population age 25 and up with a fou...       2000
# ...         ...                                                ...        ...
# 1442422   187.0     Percent of population without health insurance       2015
# 1442423   187.0     Percent of population without health insurance       2015
# 1442424   187.0     Percent of population without health insurance       2015
# 1442425   187.0     Percent of population without health insurance       2015
# 1442426   187.0     Percent of population without health insurance       2015
#
#          race_eth_code race_eth_name geotype  geotypevalue     geoname  \
# 0                  3.0     AfricanAm      CA           6.0  California
# 1                  1.0          AIAN      CA           6.0  California
# 2                  2.0         Asian      CA           6.0  California
# 3                  4.0        Latino      CA           6.0  California
# 4                  7.0      Multiple      CA           6.0  California
# ...                ...           ...     ...           ...         ...
# 1442422            5.0         NHOPI      CA           6.0  California
# 1442423            3.0     AfricanAm      CA           6.0  California
# 1442424            2.0         Asian      CA           6.0  California
# 1442425            6.0         White      CA           6.0  California
# 1442426            7.0      Multiple      CA           6.0  California
#
#         county_name  county_fips  ... County_FIPS  ll_95ci  ul_95ci rse  \
# 0               NaN          NaN  ...         NaN      NaN      NaN NaN
# 1               NaN          NaN  ...         NaN      NaN      NaN NaN
# 2               NaN          NaN  ...         NaN      NaN      NaN NaN
# 3               NaN          NaN  ...         NaN      NaN      NaN NaN
# 4               NaN          NaN  ...         NaN      NaN      NaN NaN
# ...             ...          ...  ...         ...      ...      ...  ..
# 1442422         NaN          NaN  ...         NaN      NaN      NaN NaN
# 1442423         NaN          NaN  ...         NaN      NaN      NaN NaN
# 1442424         NaN          NaN  ...         NaN      NaN      NaN NaN
# 1442425         NaN          NaN  ...         NaN      NaN      NaN NaN
# 1442426         NaN          NaN  ...         NaN      NaN      NaN NaN
#
#          ca_decile ca_rr  longitude  latitude  day  data
# 0              NaN   NaN        NaN       NaN  NaT   NaN
# 1              NaN   NaN        NaN       NaN  NaT   NaN
# 2              NaN   NaN        NaN       NaN  NaT   NaN
# 3              NaN   NaN        NaN       NaN  NaT   NaN
# 4              NaN   NaN        NaN       NaN  NaT   NaN
# ...            ...   ...        ...       ...  ...   ...
# 1442422        NaN   NaN        NaN       NaN  NaT   NaN
# 1442423        NaN   NaN        NaN       NaN  NaT   NaN
# 1442424        NaN   NaN        NaN       NaN  NaT   NaN
# 1442425        NaN   NaN        NaN       NaN  NaT   NaN
# 1442426        NaN   NaN        NaN       NaN  NaT   NaN
#
# [264 rows x 42 columns]

# %%
# make it a geo object for mapping
combo_metrics_geo = gpd.GeoDataFrame(combo_metrics_geo, 
                                     geometry = gpd.points_from_xy(combo_metrics_geo['longitude'], combo_metrics_geo['latitude']),
                                     crs = 'EPSG:4326')

fig, ax = plt.subplots(figsize=(10, 10))
world = gpd.read_file(gpd.datasets.get_path('naturalearth_lowres'))
world.plot(ax=ax, color='lightgrey')

combo_metrics_geo.plot(ax=ax, marker='o', color='blue', markersize=5, alpha=0.5)
plt.title('Climate Vulnerability Metrics')
plt.xlabel('Longitude')
plt.ylabel('Latitude')
plt.show()
# Out:
# /var/folders/n4/2w_c819n7nv4fr_mvn5wpsnc0000gn/T/ipykernel_49066/2233384457.py:7: FutureWarning: The geopandas.dataset module is deprecated and will be removed in GeoPandas 1.0. You can get the original 'naturalearth_lowres' data from https://www.naturalearthdata.com/downloads/110m-cultural-vectors/.
#   world = gpd.read_file(gpd.datasets.get_path('naturalearth_lowres'))

# %%
# isolate CA
ca_metrics_geo = combo_metrics_geo[combo_metrics_geo.geotype == 'CA']

ca_metrics_geo = ca_metrics_geo.dropna(subset=['longitude', 'latitude'])

ca_metrics_geo = ca_metrics_geo[ca_metrics_geo['longitude'].apply(lambda x: np.isfinite(x))]
ca_metrics_geo = ca_metrics_geo[ca_metrics_geo['latitude'].apply(lambda x: np.isfinite(x))]

ca_metrics_geo = gpd.GeoDataFrame(ca_metrics_geo, 
                                     geometry = gpd.points_from_xy(ca_metrics_geo['longitude'], ca_metrics_geo['latitude']),
                                     crs = 'EPSG:4326')


ca_metrics_geo.plot()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File ~/anaconda3/envs/eds-env/lib/python3.11/site-packages/pandas/core/indexes/base.py:3802, in Index.get_loc(self, key)
#    3801 try:
# -> 3802     return self._engine.get_loc(casted_key)
#    3803 except KeyError as err:
#
# File index.pyx:153, in pandas._libs.index.IndexEngine.get_loc()
#
# File index.pyx:182, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas/_libs/hashtable_class_helper.pxi:7081, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas/_libs/hashtable_class_helper.pxi:7089, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'latitude'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# /Users/sofiaingersoll/2035/iee_grid_modeling_project/identifying_ctracts_oversampling.ipynb Cell 52 line 7
#       <a href='vscode-notebook-cell:/Users/sofiaingersoll/2035/iee_grid_modeling_project/identifying_ctracts_oversampling.ipynb#Y113sZmlsZQ%3D%3D?line=3'>4</a> ca_metrics_geo = ca_metrics_geo.dropna(subset=['longitude', 'latitude'])
#       <a href='vscode-notebook-cell:/Users/sofiaingersoll/2035/iee_grid_modeling_project/identifying_ctracts_oversampling.ipynb#Y113sZmlsZQ%3D%3D?line=5'>6</a> ca_metrics_geo = ca_metrics_geo[ca_metrics_geo['longitude'].apply(lambda x: np.isfinite(x))]
# ----> <a href='vscode-notebook-cell:/Users/sofiaingersoll/2035/iee_grid_modeling_project/identifying_ctracts_oversampling.ipynb#Y113sZmlsZQ%3D%3D?line=6'>7</a> ca_metrics_geo = ca_metrics_geo[ca_metrics_geo['latitude'].apply(lambda x: np.isfinite(x))]
#       <a href='vscode-notebook-cell:/Users/sofiaingersoll/2035/iee_grid_modeling_project/identifying_ctracts_oversampling.ipynb#Y113sZmlsZQ%3D%3D?line=8'>9</a> ca_metrics_geo = gpd.GeoDataFrame(ca_metrics_geo,
#      <a href='vscode-notebook-cell:/Users/sofiaingersoll/2035/iee_grid_modeling_project/identifying_ctracts_oversampling.ipynb#Y113sZmlsZQ%3D%3D?line=9'>10</a>                                      geometry = gpd.points_from_xy(ca_metrics_geo['longitude'], ca_metrics_geo['latitude']),
#      <a href='vscode-notebook-cell:/Users/sofiaingersoll/2035/iee_grid_modeling_project/identifying_ctracts_oversampling.ipynb#Y113sZmlsZQ%3D%3D?line=10'>11</a>                                      crs = 'EPSG:4326')
#      <a href='vscode-notebook-cell:/Users/sofiaingersoll/2035/iee_grid_modeling_project/identifying_ctracts_oversampling.ipynb#Y113sZmlsZQ%3D%3D?line=13'>14</a> ca_metrics_geo.plot()
#
# File ~/anaconda3/envs/eds-env/lib/python3.11/site-packages/pandas/core/frame.py:4090, in DataFrame.__getitem__(self, key)
#    4088 if self.columns.nlevels > 1:
#    4089     return self._getitem_multilevel(key)
# -> 4090 indexer = self.columns.get_loc(key)
#    4091 if is_integer(indexer):
#    4092     indexer = [indexer]
#
# File ~/anaconda3/envs/eds-env/lib/python3.11/site-packages/pandas/core/indexes/base.py:3809, in Index.get_loc(self, key)
#    3804     if isinstance(casted_key, slice) or (
#    3805         isinstance(casted_key, abc.Iterable)
#    3806         and any(isinstance(x, slice) for x in casted_key)
#    3807     ):
#    3808         raise InvalidIndexError(key)
# -> 3809     raise KeyError(key) from err
#    3810 except TypeError:
#    3811     # If we have a listlike key, _check_indexing_error will raise
#    3812     #  InvalidIndexError. Otherwise we fall through and re-raise
#    3813     #  the TypeError.
#    3814     self._check_indexing_error(key)
#
# KeyError: 'latitude'

# %% [markdown]
# ### DOE's Energy Justice Mapping Tool - Disadvantaged Communities Reporter (EJMT)

# %%
doe_ejmt = gpd.read_file('../data/DOE_EJ_mapping_tool/DAC Shapefiles (v2022c).shp',
                         crs = sb535_geo.crs)

doe_ejmt = to_snake_case(doe_ejmt)

doe_ejmt_ca = doe_ejmt[doe_ejmt.stateabb == 'CA']

doe_ejmt_ca
# Out:
#              geoid              city                     county stateabb  \
# 263    06003010000      Markleeville          Alpine County, CA       CA
# 264    06007001300             Chico           Butte County, CA       CA
# 266    06015000203           Klamath       Del Norte County, CA       CA
# 267    06023010102      Willow Creek        Humboldt County, CA       CA
# 268    06023940000              None        Humboldt County, CA       CA
# ...            ...               ...                        ...      ...
# 71260  06071010417    Morongo Valley  San Bernardino County, CA       CA
# 71262  06071010415  Twentynine Palms  San Bernardino County, CA       CA
# 71264  06071010421  Twentynine Palms  San Bernardino County, CA       CA
# 72940  06059990100              None          Orange County, CA       CA
# 73031  06061990000              None          Placer County, CA       CA
#
#       countyfips   cbsa                              cbsaname statefips  \
# 263         6003  99999                                  None         6
# 264         6007  17020                             Chico, CA         6
# 266         6015  18860                     Crescent City, CA         6
# 267         6023  21700                     Eureka-Arcata, CA         6
# 268         6023  21700                     Eureka-Arcata, CA         6
# ...          ...    ...                                   ...       ...
# 71260       6071  40140  Riverside-San Bernardino-Ontario, CA         6
# 71262       6071  40140  Riverside-San Bernardino-Ontario, CA         6
# 71264       6071  40140  Riverside-San Bernardino-Ontario, CA         6
# 72940       6059  31080    Los Angeles-Long Beach-Anaheim, CA         6
# 73031       6061  40900       Sacramento-Roseville-Folsom, CA         6
#
#        population  dacsts  ...  disablpct  incplmbpct  snglpntpct  mobilhmpct  \
# 263        1039.0       0  ...   0.159769    0.000000    0.386503    0.017946
# 264        3689.0       0  ...   0.173486    0.000000    0.485294    0.034864
# 266        1251.0       0  ...   0.301920    0.008811    0.634615    0.432810
# 267        2423.0       0  ...   0.210196    0.012333    0.100683    0.073875
# 268        3263.0       0  ...   0.205648    0.062147    0.740831    0.334879
# ...           ...     ...  ...        ...         ...         ...         ...
# 71260      2931.0       0  ...   0.176731    0.000000    0.309859    0.075137
# 71262      5316.0       0  ...   0.232675    0.000000    0.465098    0.015801
# 71264      6003.0       0  ...   0.200203    0.012821    0.434954    0.017824
# 72940         0.0       0  ...   0.000000    0.000000    0.000000    0.000000
# 73031         0.0       0  ...   0.000000    0.000000    0.000000    0.000000
#
#        nongridpct  lesshspct  lowincfpct  lowincapct  eal_npctl  \
# 263      0.848571   0.088312    0.388835    0.232877  98.801193
# 264      0.032665   0.200159    0.514184    0.539340  91.930051
# 266      0.607930   0.181319    0.539267    0.416000  75.575688
# 267      0.770812   0.064706    0.385290    0.447674  84.305531
# 268      0.841808   0.120198    0.651013    0.383959  70.934437
# ...           ...        ...         ...         ...        ...
# 71260    0.258493   0.076227    0.397134    0.277683  89.126878
# 71262    0.048458   0.147978    0.297216    0.283658  88.066924
# 71264    0.074204   0.084351    0.630327    0.417069  90.001237
# 72940    0.000000   0.000000    0.000000         NaN        NaN
# 73031    0.000000   0.000000    0.000000         NaN        NaN
#
#                                                 geometry
# 263    POLYGON ((-13366398.426 4679189.192, -13365864...
# 264    POLYGON ((-13562009.036 4826320.661, -13561775...
# 266    POLYGON ((-13820782.324 5120426.256, -13819546...
# 267    POLYGON ((-13807602.096 5081143.191, -13803750...
# 268    POLYGON ((-13782844.641 5035659.850, -13773282...
# ...                                                  ...
# 71260  POLYGON ((-12982335.051 4038245.509, -12982079...
# 71262  POLYGON ((-12924994.381 4051867.053, -12924972...
# 71264  POLYGON ((-12921899.700 4045531.610, -12921576...
# 72940                                               None
# 73031  POLYGON ((-13376361.521 4735661.593, -13376138...
#
# [8057 rows x 51 columns]

# %%
doe_ejmt_ca.plot()
# Out:
# <Axes: >

# %% [markdown]
# ### CDC's Environmental Justice Index (EJI)
#
# location = Census Tract 4001; Alameda County; California

# %%
cdc_eji = to_snake_case(pd.read_csv('../data/CDC_Index/California_EJ.csv'))

cdc_eji_ca = cdc_eji[cdc_eji.stateabbr == 'CA']

# %%
cdc_eji_ca_geo = gpd.GeoDataFrame(cdc_eji_ca)

# let's see if there is a geometry column if we don't set it 
# obvi no, so the cdc data will need to be added to the schema assignment plan 
# these cdc won't be included in the simple_wkflw.ipynb outputs
cdc_eji_ca_geo.geometry
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# /Users/sofiaingersoll/2035/iee_grid_modeling_project/identifying_ctracts_oversampling.ipynb Cell 58 line 3
#       <a href='vscode-notebook-cell:/Users/sofiaingersoll/2035/iee_grid_modeling_project/identifying_ctracts_oversampling.ipynb#Y122sZmlsZQ%3D%3D?line=0'>1</a> cdc_eji_ca_geo = gpd.GeoDataFrame(cdc_eji_ca)
# ----> <a href='vscode-notebook-cell:/Users/sofiaingersoll/2035/iee_grid_modeling_project/identifying_ctracts_oversampling.ipynb#Y122sZmlsZQ%3D%3D?line=2'>3</a> cdc_eji_ca_geo.geometry
#
# File ~/anaconda3/envs/eds-env/lib/python3.11/site-packages/pandas/core/generic.py:6293, in NDFrame.__getattr__(self, name)
#    6286 if (
#    6287     name not in self._internal_names_set
#    6288     and name not in self._metadata
#    6289     and name not in self._accessors
#    6290     and self._info_axis._can_hold_identifiers_and_holds_name(name)
#    6291 ):
#    6292     return self[name]
# -> 6293 return object.__getattribute__(self, name)
#
# File ~/anaconda3/envs/eds-env/lib/python3.11/site-packages/geopandas/geodataframe.py:235, in GeoDataFrame._get_geometry(self)
#     228     else:
#     229         msg += (
#     230             "\nThere are no existing columns with geometry data type. You can "
#     231             "add a geometry column as the active geometry column with "
#     232             "df.set_geometry. "
#     233         )
# --> 235     raise AttributeError(msg)
#     236 return self[self._geometry_column_name]
#
# AttributeError: You are calling a geospatial method on the GeoDataFrame, but the active geometry column to use has not been set.
# There are no existing columns with geometry data type. You can add a geometry column as the active geometry column with df.set_geometry.

# %%
cdc_eji_ca.plot()

# %% [markdown]
# ### CDC's Social Vulnerability Index (SVI)
# `fips` needs to be put in sci-not

# %%
cdc_svi = to_snake_case(pd.read_csv('../data/CDC_Index/California_SVI.csv'))

cdc_svi
#cdc_svi_ca = cdc_svi[cdc_svi.st_abbr == 'CA']
# Out:
#       st       state st_abbr  stcnty          county        fips  \
# 0      6  California      CA    6001  Alameda County  6001400100
# 1      6  California      CA    6001  Alameda County  6001400200
# 2      6  California      CA    6001  Alameda County  6001400300
# 3      6  California      CA    6001  Alameda County  6001400400
# 4      6  California      CA    6001  Alameda County  6001400500
# ...   ..         ...     ...     ...             ...         ...
# 9104   6  California      CA    6115     Yuba County  6115040902
# 9105   6  California      CA    6115     Yuba County  6115041001
# 9106   6  California      CA    6115     Yuba County  6115041002
# 9107   6  California      CA    6115     Yuba County  6115041101
# 9108   6  California      CA    6115     Yuba County  6115041102
#
#                                            location   area_sqmi  e_totpop  \
# 0     Census Tract 4001; Alameda County; California    2.681809      3269
# 1     Census Tract 4002; Alameda County; California    0.226472      2147
# 2     Census Tract 4003; Alameda County; California    0.428898      5619
# 3     Census Tract 4004; Alameda County; California    0.276502      4278
# 4     Census Tract 4005; Alameda County; California    0.228350      3949
# ...                                             ...         ...       ...
# 9104   Census Tract 409.02; Yuba County; California   36.140330      1868
# 9105   Census Tract 410.01; Yuba County; California  106.533509      3672
# 9106   Census Tract 410.02; Yuba County; California   74.315667      3417
# 9107   Census Tract 411.01; Yuba County; California  179.500889      2288
# 9108   Census Tract 411.02; Yuba County; California   36.452246      1010
#
#       m_totpop  ...  ep_asian  mp_asian  ep_aian  mp_aian  ep_nhpi  mp_nhpi  \
# 0          452  ...      14.6       3.7      0.0      1.2      0.0      1.2
# 1          201  ...      11.7       4.5      0.4      0.7      0.0      1.8
# 2          571  ...      11.3       3.3      0.5      0.5      0.0      0.7
# 3          598  ...       8.7       2.7      0.5      0.7      0.0      0.9
# 4          737  ...       9.4       4.5      0.1      0.2      0.2      0.3
# ...        ...  ...       ...       ...      ...      ...      ...      ...
# 9104       173  ...       4.4       3.1      0.2      0.3      0.5      0.8
# 9105       751  ...       0.0       1.1      0.3      0.7      0.0      1.1
# 9106       584  ...       0.8       1.2      0.0      1.2      0.3      0.6
# 9107       718  ...       0.0       1.7      0.7      1.2      0.0      0.1
# 9108       214  ...       0.9       2.1      0.0      3.9      2.4      4.6
#
#       ep_twomore  mp_twomore  ep_otherrace  mp_otherrace
# 0            5.3         2.7           0.8           0.9
# 1            8.5         3.4           0.4           0.5
# 2            9.1         4.8           1.1           1.0
# 3            7.7         3.1           0.2           0.2
# 4            8.3         5.0           0.0           1.0
# ...          ...         ...           ...           ...
# 9104         4.0         2.8           0.0           2.1
# 9105         4.9         3.6           0.0           1.1
# 9106        11.4         7.6           0.0           1.2
# 9107         4.9         2.8           0.0           1.7
# 9108         0.0         3.9           0.0           3.9
#
# [9109 rows x 158 columns]

# %% [markdown]
# ### US Climate Vulnerability Index: Overall Climate Vulnerability in The U.S.
#
# okay I took a png of the map I was interested in and converted it into a tif, so the data was not properly adheased for parsing and the coordinate boundaries and resolution need to be defined. I believe that would resolve the error below. Saving for round 2 after schema is corrected.

# %%
us_overall_cv = rioxr.open_rasterio('../data/us_overall_climate_vulnerability.tif',
                                    crs = sb535_geo.crs)
us_overall_cv
# Out:
# /Users/sofiaingersoll/anaconda3/envs/eds-env/lib/python3.11/site-packages/rioxarray/_io.py:1132: NotGeoreferencedWarning: Dataset has no geotransform, gcps, or rpcs. The identity matrix will be returned.
#   warnings.warn(str(rio_warning.message), type(rio_warning.message))  # type: ignore
# <xarray.DataArray (band: 4, y: 2940, x: 4000)>
# [47040000 values with dtype=uint8]
# Coordinates:
#   * band         (band) int64 1 2 3 4
#   * x            (x) float64 0.5 1.5 2.5 3.5 ... 3.998e+03 3.998e+03 4e+03
#   * y            (y) float64 0.5 1.5 2.5 3.5 ... 2.938e+03 2.938e+03 2.94e+03
#     spatial_ref  int64 0
# Attributes:
#     TIFFTAG_XRESOLUTION:  96
#     TIFFTAG_YRESOLUTION:  96
#     scale_factor:         1.0
#     add_offset:           0.0

# %%
us_overall_cv.plot()
# Out:
# (array([  106553.,   476592.,   597541.,   563441.,   448098.,   482266.,
#           710691.,   951070., 18057794., 24645954.]),
#  array([  0. ,  25.5,  51. ,  76.5, 102. , 127.5, 153. , 178.5, 204. ,
#         229.5, 255. ]),
#  <BarContainer object of 10 artists>)

# %% [markdown]
# #### Mapping

# %% [markdown]
# #### Interpretting
#
# Include explanation of CalEnviroScreen Scores
